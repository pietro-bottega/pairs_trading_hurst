# %% [markdown]
# ## Map bear market periods and then classify dates analyzed

# %% [markdown]
# Assumptions:
# - `distance_gatev.py` scrip inputs dates ordered cardinally, so there is no clear indication of exact date
# - Therefore we are assuming it follows all dates that US stock exchanges operate, since start date (not clearly stated, so assuming `1990-01-01`)
# - This means it does not include weekdays and holidays (using US Fedaral Holiday Calendar)
# - The operation is classified as bear market if it started in a date within a bear market period

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta
from pandas.tseries.offsets import *
from pandas.tseries.holiday import USFederalHolidayCalendar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading table present on the file about bear markets in history

bear_markets = pd.read_csv("../crisis_analysis/bear_markets.csv")
bear_markets = bear_markets.drop(columns=['return_percentage','days_duration'])

type_mapping = {
    'start': 'datetime64[ns]',
    'end': 'datetime64[ns]'
}

bear_markets = bear_markets.astype(type_mapping) #ensuring dtype is datetime
bear_markets.head(5)
# Out:
#        start        end
# 0 1929-09-07 1929-11-13
# 1 1930-04-10 1930-12-16
# 2 1931-02-24 1931-06-02
# 3 1931-06-27 1931-10-05
# 4 1931-11-09 1932-06-01

# %%
def create_daily_bear_market_indicator(bear_markets):
    '''
    Transform a dataframe of bear market start and end dates into a daily time series
    with an indicator for whether each date is in a bear market.
    
    Parameters:
    -----------
    bear_periods_df : pandas.DataFrame
        DataFrame with 'start' and 'end' columns containing dates of bear market periods
    
    Returns:
    --------
    pandas.DataFrame
        Daily time series with columns 'date' and 'is_bear_market'
    '''
    
    min_date = bear_markets['start'].min()
    max_date = bear_markets['end'].max()
    
    date_range = pd.date_range(start=min_date, end=max_date, freq='D')
    daily_df = pd.DataFrame({'date': date_range})
    
    daily_df['is_bear_market'] = 0
    
    for _, row in bear_markets.iterrows():
        mask = (daily_df['date'] >= row['start']) & (daily_df['date'] <= row['end'])
        daily_df.loc[mask, 'is_bear_market'] = 1
        
    return daily_df

# %%
# Applying function to create dataframe of dates and indication if it is during a bear market
daily_bear_market = create_daily_bear_market_indicator(bear_markets)
daily_bear_market.head(1)
# Out:
#         date  is_bear_market
# 0 1929-09-07               1

# %%
def list_business_days(start_date, end_date):
    us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())
    date_range = pd.date_range(start=start_date, end=end_date, freq=us_bd)
    return [date.date() for date in date_range]

start_date = '1990-01-01'
end_date = '2015-12-31'
business_days = pd.DataFrame(list_business_days(start_date, end_date), columns=['date']).astype({'date': 'datetime64[ns]'})
business_days
# Out:
#            date
# 0    1990-01-02
# 1    1990-01-03
# 2    1990-01-04
# 3    1990-01-05
# 4    1990-01-08
# ...         ...
# 6519 2015-12-24
# 6520 2015-12-28
# 6521 2015-12-29
# 6522 2015-12-30
# 6523 2015-12-31
#
# [6524 rows x 1 columns]

# %%
analysis_period_classified = pd.merge(
    left = business_days,
    right = daily_bear_market,
    left_on = 'date',
    right_on = 'date',
    how = 'inner'
).reset_index()

analysis_period_classified
# Out:
#       index       date  is_bear_market
# 0         0 1990-01-02               0
# 1         1 1990-01-03               0
# 2         2 1990-01-04               0
# 3         3 1990-01-05               0
# 4         4 1990-01-08               0
# ...     ...        ...             ...
# 6519   6519 2015-12-24               0
# 6520   6520 2015-12-28               0
# 6521   6521 2015-12-29               0
# 6522   6522 2015-12-30               0
# 6523   6523 2015-12-31               0
#
# [6524 rows x 3 columns]

# %% [markdown]
# ## Classify Distance methods operations

# %%
operations = pd.read_csv("../distance_results/operations.csv").drop(columns=['Unnamed: 0'])
operations
# Out:
#       Semester  Days   S1        S2          Pair    Return  Converged  \
# 0            0    33  JCI  1436513D  JCI-1436513D  1.000034       True
# 1            0    13  JCI  1436513D  JCI-1436513D  1.000067       True
# 2            0    28  JCI  1436513D  JCI-1436513D  1.000088       True
# 3            0     9  JCI  1436513D  JCI-1436513D  1.000049       True
# 4            0    17  JCI  1436513D  JCI-1436513D  1.000052       True
# ...        ...   ...  ...       ...           ...       ...        ...
# 2740        48     8  XEL       WEC       XEL-WEC  1.022778       True
# 2741        48     7  XEL       WEC       XEL-WEC  1.024433       True
# 2742        48    10  PNW       WEC       PNW-WEC  1.020942       True
# 2743        48     5  PNW       WEC       PNW-WEC  1.018191       True
# 2744        48    43  SPG       PSA       SPG-PSA  0.950000      False
#
#       Count day
# 0            33
# 1            47
# 2            78
# 3            87
# 4           105
# ...         ...
# 2740       6106
# 2741       6117
# 2742       6070
# 2743       6106
# 2744       6040
#
# [2745 rows x 8 columns]

# %%
operations = pd.merge(
    left = operations,
    right = analysis_period_classified,
    left_on = 'Count day',
    right_on = 'index',
    how = 'left'
).drop(columns=['index'])

operations
# Out:
#       Semester  Days   S1        S2          Pair    Return  Converged  \
# 0            0    33  JCI  1436513D  JCI-1436513D  1.000034       True
# 1            0    13  JCI  1436513D  JCI-1436513D  1.000067       True
# 2            0    28  JCI  1436513D  JCI-1436513D  1.000088       True
# 3            0     9  JCI  1436513D  JCI-1436513D  1.000049       True
# 4            0    17  JCI  1436513D  JCI-1436513D  1.000052       True
# ...        ...   ...  ...       ...           ...       ...        ...
# 2740        48     8  XEL       WEC       XEL-WEC  1.022778       True
# 2741        48     7  XEL       WEC       XEL-WEC  1.024433       True
# 2742        48    10  PNW       WEC       PNW-WEC  1.020942       True
# 2743        48     5  PNW       WEC       PNW-WEC  1.018191       True
# 2744        48    43  SPG       PSA       SPG-PSA  0.950000      False
#
#       Count day       date  is_bear_market
# 0            33 1990-02-20               0
# 1            47 1990-03-12               0
# 2            78 1990-04-24               0
# 3            87 1990-05-07               0
# 4           105 1990-06-01               0
# ...         ...        ...             ...
# 2740       6106 2014-05-02               0
# 2741       6117 2014-05-19               0
# 2742       6070 2014-03-13               0
# 2743       6106 2014-05-02               0
# 2744       6040 2014-01-29               0
#
# [2745 rows x 10 columns]

# %% [markdown]
# ## Results Analysis

# %%
operations['is_bear_market'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2740    0
# 2741    0
# 2742    0
# 2743    0
# 2744    0
# Name: is_bear_market, Length: 2745, dtype: int64>

# %%
operations[operations['is_bear_market']==1]['Return'].describe()
# Out:
# count    390.000000
# mean       1.008389
# std        0.040569
# min        0.950000
# 25%        0.970641
# 50%        1.018776
# 75%        1.034404
# max        1.149781
# Name: Return, dtype: float64

# %%
operations[operations['is_bear_market']==0]['Return'].describe()
# Out:
# count    2355.000000
# mean        1.005093
# std         0.036546
# min         0.950000
# 25%         0.977459
# 50%         1.016312
# 75%         1.028792
# max         1.244459
# Name: Return, dtype: float64

# %%
operations['excess_return'] = operations['Return'] - 1
operations
# Out:
#       Semester  Days   S1        S2          Pair    Return  Converged  \
# 0            0    33  JCI  1436513D  JCI-1436513D  1.000034       True
# 1            0    13  JCI  1436513D  JCI-1436513D  1.000067       True
# 2            0    28  JCI  1436513D  JCI-1436513D  1.000088       True
# 3            0     9  JCI  1436513D  JCI-1436513D  1.000049       True
# 4            0    17  JCI  1436513D  JCI-1436513D  1.000052       True
# ...        ...   ...  ...       ...           ...       ...        ...
# 2740        48     8  XEL       WEC       XEL-WEC  1.022778       True
# 2741        48     7  XEL       WEC       XEL-WEC  1.024433       True
# 2742        48    10  PNW       WEC       PNW-WEC  1.020942       True
# 2743        48     5  PNW       WEC       PNW-WEC  1.018191       True
# 2744        48    43  SPG       PSA       SPG-PSA  0.950000      False
#
#       Count day       date  is_bear_market  excess_return
# 0            33 1990-02-20               0       0.000034
# 1            47 1990-03-12               0       0.000067
# 2            78 1990-04-24               0       0.000088
# 3            87 1990-05-07               0       0.000049
# 4           105 1990-06-01               0       0.000052
# ...         ...        ...             ...            ...
# 2740       6106 2014-05-02               0       0.022778
# 2741       6117 2014-05-19               0       0.024433
# 2742       6070 2014-03-13               0       0.020942
# 2743       6106 2014-05-02               0       0.018191
# 2744       6040 2014-01-29               0      -0.050000
#
# [2745 rows x 11 columns]

# %%
comparison_markets = operations.groupby('is_bear_market')['Return'].mean().to_frame()
comparison_markets

# Boxplot style
sns.set_theme(style='darkgrid')
fig = plt.subplots(figsize=(8, 6))

# Plot data
ax = sns.barplot(comparison_markets, x='is_bear_market', y='Return')

ax.set_title('Mean of return from distance method by market moment')
ax.set_xlabel('Bear market classification (Bear market = 1)', labelpad=10)
ax.set_ylabel('Mean return', labelpad=10)
ax.set_ylim(1, 1.01)
# Out:
# (1.0, 1.01)

# %%
sns.histplot(data=operations, x='excess_return', hue='is_bear_market', element='step')
# Out:
# <Axes: xlabel='excess_return', ylabel='Count'>
