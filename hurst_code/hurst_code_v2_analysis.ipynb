# %%
import math
import numpy as np
import pandas as pd
from tqdm import tqdm
from collections import Counter
import scipy.stats
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore', category=FutureWarning) #remove python standard warning and have clear output


periods = pd.read_csv("../distance_data/Periods.csv", header=None)
Pt = pd.read_csv("../distance_data/Pt_formatted.csv", header=0)
Rt = pd.read_csv("../distance_data/Rt_formatted.csv", header=0)
Rm = pd.read_csv("../distance_data/Rm.csv", header=None)
Rf = pd.read_csv("../distance_data/Rf.csv", header=None)
Vt = pd.read_csv("../distance_data/Vt.csv", header=None)
ticker2 = pd.read_csv("../distance_data/ticker2.csv", header=None)
ticker_b = pd.read_csv("../distance_data/ticker_b.csv", header=None)

# --------------------------------------
# Defining parameters for analysis
# --------------------------------------

days, num_assets = np.shape(Rt)

print(f"Days: {days} | Assets: {num_assets}")

daylag = 0
wi_update = 1
years = 2015 - 1990 + 0.5

no_pairs = 10 # number of pairs to be selected and used in operations
candidate_pool_size = 500 # We will first select the 500 best pairs using the distance method.

trading_costs = 0 # absolute trading cost
percentage_costs = 0.002 # buy/sell (percentage cost for opening and closing pairs: 0.001, 0.002, for example)
trade_req = 0 # set whether (0) or not (2) positive trading volume is required for opening/closing a pair
Stop_loss = 0.95 # Choose how much loss we are willing to accept on a given pair, compared to 1, i.e, 0.93 = 7% stop loss

if Stop_loss != float('-inf'):
    stop_dir = 100 - (Stop_loss * 100)
Stop_gain = float('inf') # Choose how much gain we are willing to accept on a given pair, compared to 1, i.e 1.10 = 10% stop gain, set float('inf') if no limit for gain
s1218 = 1  # listing req. (look ahead): 12+6 months (=1)

opening_threshold = 1.5
closing_threshold = 0.75

duration_limit = float('inf')

avg_price_dev = np.zeros(
    (days-sum(periods.iloc[0:2, 0].to_list()), no_pairs*2))
# 12 months are w/o price deviations. The first 12 months are formation period

# --------------------------------------
# Creating blank matrices and arrays to store
# --------------------------------------

# Operations array
operations = []

# Keeps track of the return of each pair
first_traininig = int(periods.iloc[0, 3])
Rpair = np.zeros((days-first_traininig, no_pairs))
Rp_ew_cc = pd.DataFrame(np.zeros((days-first_traininig, 2)),
                        columns=['Return', 'Semester'])
Rp_vw_fi = pd.DataFrame(np.zeros((days-first_traininig, 2)),
                        columns=['Return', 'Semester'])
ret_acum_df = pd.DataFrame(
    np.zeros((days-first_traininig, 4)), columns=['CC', 'FI', 'RMRF', 'SEMESTER'])
RmRf = np.zeros((days-first_traininig, 1))
risk_free = pd.DataFrame(np.zeros((days-first_traininig, 2)),
                        columns=['Return', 'Semester'])

periods_with_open_pair = 0  # number of periods with pairs opened
periods_without_open_pair = 0  # number of periods without pairs opened
pairs_number = 0
pair_open = 0
days_open = np.zeros((no_pairs*10000, 1))
# measures number of days each pair open; bad programming, but we do not know how many pairs we get
# measures number of times pairs opened in each pair per 6 month period
no_pairs_opened = np.zeros((int(years*2-2), no_pairs))

counter = 0  # Keeps track of the days in the main loop

asset_frequency_counter = Counter() # later used to track how many times each stock is selected

# --------------------------------------
# Defining functions for Hurst Exponent 
# --------------------------------------

def calculate_rs_for_lag(time_series, lag):
    """
    Calculate the Rescaled Range (R/S) for a specific lag.

    Args:
        time_series (array-like): The time series data.
        lag (int): The lag to use for the calculation.

    Returns:
        float: The Rescaled Range (R/S) value.
    """
    # 1. O procedimento a seguir é realizado para diversos subperíodos ou partições dentro da série original
    sub_series_list = [time_series[i:i+lag] for i in range(0, len(time_series), lag)]

    # 2. Cada série temporal é convertida em uma série de totais acumulados dos seus desvios em relação à média.
    mean_adjusted_cumulative_sums = []
    for sub_series in sub_series_list:
        mean = np.mean(sub_series)
        mean_adjusted_series = sub_series - mean
        cumulative_sum = np.cumsum(mean_adjusted_series)
        mean_adjusted_cumulative_sums.append(cumulative_sum)

    # 3. Cálculo da estatística "Rescaled Range" ou R/S
    ranges = []
    std_devs = []
    for i in range(len(sub_series_list)): 
        # 3.1. O "Range" (R) é então definido como a diferença entre o valor máximo e o mínimo desta série acumulada.
        ranges.append(np.max(mean_adjusted_cumulative_sums[i]) - np.min(mean_adjusted_cumulative_sums[i]))
        # 3.2. O "Standard Deviation" (S) ou desvio padrão é calculado para cada série
        std_devs.append(np.std(sub_series_list[i]))

    # 4. O valor de R é normalizado ao ser dividido por S das observações da série original.
    avg_rescaled_range = np.mean([ranges[i] / std_devs[i] for i in range(len(ranges)) if std_devs[i] > 0])

    return avg_rescaled_range

def calculate_hurst_rs(time_series):
    """
    Calculate the Hurst exponent of a time series using Rescaled Range (R/S) analysis.

    Args:
        time_series (array-like): The time series data.

    Returns:
        float: The Hurst exponent.
    """
    n = len(time_series)
    if n < 20:
        raise ValueError("Time series must have at least 20 data points.")

    # 5. Criar uma lista de partições
    lags = range(2, n)

    # 6. Calcular o R/S para cada uma das partições:
    rescaled_ranges = [calculate_rs_for_lag(time_series, lag) for lag in lags]

    # 7. Estimativa via Regressão Linear
    # A relação entre os valores de R/S e os seus respectivos tamanhos de partição (n) segue uma lei de potência.
    # Ao aplicar logaritmos a essa relação, o expoente de Hurst é finalmente estimado por meio de uma regressão linear simples
    # Correspondendo ao coeficiente angular da reta que ajusta o logaritmo de R/S em função do logaritmo de n.
    hurst_exponent = np.polyfit(np.log(lags), np.log(rescaled_ranges), 1)[0]

    return hurst_exponent

# ----------------------------------------------------
# Start of Main Loop - Creating Price Index
# ----------------------------------------------------

big_loop = 0
i = 0

while big_loop < (years * 2 - 2):
    twelve_months = int(periods.iloc[big_loop, 3])
    six_months = int(periods.iloc[big_loop + 2, 0])

    print(
        f"\n================ Period {big_loop} ================")
    print(
        f"Formation Period: {twelve_months} days | Trading Period: {six_months} days")
    

    # ----------------------------------------------------
    # Create price index IPt by setting first Pt>0 to 1
    # ----------------------------------------------------

    # Preallocate a zeros matrix with the size of the Formation + Trading period
    # IPt = Indexed Price at time t
    IPt = np.zeros((int(twelve_months + six_months), num_assets))

    print("Generating Assets Price Index")

    for j in tqdm(range(0, num_assets)):
        m = 0
        for i2 in range(0, int(twelve_months+six_months)):  # same here
            if not math.isnan(Pt.iloc[i+i2, j]) and m == 0:
                IPt[i2, j] = 1
                m = 1
            elif not math.isnan(Pt.iloc[i+i2, j]) and m == 1:
                IPt[i2, j] = IPt[i2-1, j] * (1 + Rt.iloc[i+i2, j])

    pd.DataFrame(IPt).to_csv("IPt.csv", header=None,
                             index=False, na_rep='NULL')

    listed1 = IPt[0, :] > 0
    listed2 = IPt[int(twelve_months+six_months*(s1218 == 1))-1, :] > 0
    listed = np.multiply(listed1, listed2)

    listed_num = np.sum(listed)
    listed_indexes = np.where(listed > 0)[0]
    listed_stocks = Pt.columns[listed_indexes]

    [D, ia, ib] = np.intersect1d(
        ticker2.iloc[:, big_loop], ticker2.iloc[:, big_loop+1], return_indices=True)

    ic = np.isin(D, ticker2.iloc[:, big_loop+2])

    Dic_unique_sorted, B_idx = np.unique(D[ic], return_index=True)

    listed_union = np.intersect1d(listed_stocks, Dic_unique_sorted)

    index_listed2 = [Pt.columns.get_loc(i) for i in listed_union if i in Pt]
    index_listed2.sort()

    no_listed2 = len(index_listed2)
    print(f"Number of listed stocks in period: {no_listed2}")

    # ----------------------------------------------------
    # Add filters (if needed)
    # ----------------------------------------------------
    no_comp = np.transpose(sum(np.transpose(IPt > 0)))
    print(f'Period {big_loop}')

    # ----------------------------------------------------
    # Pair selection with Hurst Exponent
    # ----------------------------------------------------
    print("--- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---")
    
    # --- STAGE 1: Fast pre-selection using Sum of Squared Errors (SSE) ---

    # Use np.inf as a sentinel for pairs that are not calculated or already selected.
    sse = np.full((no_listed2, no_listed2), np.inf) 
    for j in tqdm(range(no_listed2 - 1), desc="Stage 1: Calculating SSE"):
        for k in range(j + 1, no_listed2):
            sse[j, k] = np.sum(np.power(IPt[0:int(twelve_months), index_listed2[j]] - IPt[0:int(twelve_months), index_listed2[k]], 2))

    # Find the top 'candidate_pool_size' pairs with the lowest SSE
    candidate_pairs_indices = []
    sse_copy = sse.copy()

    # Ensure we don't try to select more candidates than there are pairs
    num_to_select = min(candidate_pool_size, (no_listed2 * (no_listed2 - 1)) // 2)
    if num_to_select > 0:
        for _ in range(num_to_select):
            # Find the minimum SSE value that is not infinity
            min_sse_val = np.nanmin(sse_copy)
            if np.isinf(min_sse_val):
                break # Stop if no finite values are left
            
            ro_list, co_list = np.where(sse_copy == min_sse_val)
            ro, co = ro_list[0], co_list[0]
            
            candidate_pairs_indices.append({'ro': ro, 'co': co})
            
            # Mark this pair as selected by setting its SSE to infinity
            sse_copy[ro, co] = np.inf

    print(f"--- Stage 1 Complete: {len(candidate_pairs_indices)} candidate pairs selected. ---")
    print("--- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---")

    # --- STAGE 2: Calculate Hurst Exponent ONLY for the pre-selected candidates ---
    hurst_results = []
    for pair_idx in tqdm(candidate_pairs_indices, desc="Stage 2: Calculating Hurst"):
        j = pair_idx['ro']
        k = pair_idx['co']
        
        try:
            spread_series = IPt[0:int(twelve_months), index_listed2[j]] - IPt[0:int(twelve_months), index_listed2[k]]
            spread_diff = np.diff(spread_series)

            if np.std(spread_diff) > 1e-6: # Check for non-zero variance
                h_exponent = calculate_hurst_rs(spread_diff)
                hurst_results.append({'ro': j, 'co': k, 'hurst': h_exponent})
        except Exception:
            continue # Skip if Hurst calculation fails for any reason

    print("--- Stage 2 Complete. Finalizing pair selection... ---")

    # --- FINAL SELECTION: Sort candidates by Hurst and select the top 'no_pairs' ---
    hurst_results.sort(key=lambda x: x['hurst'])
    final_selection = hurst_results[:no_pairs]

    print("\n--- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---")
    if not final_selection:
        print("No pairs were selected for this period.")
    else:
        for idx, selection in enumerate(final_selection):
            ro = selection['ro']
            co = selection['co']
            hurst_val = selection['hurst']
            ticker1_name = Pt.columns[index_listed2[ro]]
            ticker2_name = Pt.columns[index_listed2[co]]
            # Print rank, pair tickers, and the formatted Hurst Exponent
            print(f"{idx + 1:2d}. Pair: {ticker1_name:>7}-{ticker2_name:<7} | Hurst: {hurst_val:.4f}")
    print("------------------------------------------------------------------\n")

    pairs = []
    for selection in final_selection:
        ro = selection['ro']
        co = selection['co']
        pairs.append({
            "s1_col": int(ro), 
            "s2_col": int(co),
            "s1_ticker": Pt.columns[index_listed2[ro]], 
            "s2_ticker": Pt.columns[index_listed2[co]]
        })

    # This will be used to create final analysis in the end
    for pair_data in pairs:
        asset_frequency_counter[pair_data['s1_ticker']] += 1
        asset_frequency_counter[pair_data['s2_ticker']] += 1

    if len(pairs) < no_pairs:
        print(f"Warning: Only {len(pairs)} pairs were selected after Hurst filtering.")

    # ----------------------------------------------------
    # Calculate returns during the 6 month period
    # ----------------------------------------------------

    count_temp = counter

    print(f"counter value: {counter} | counter_temp = {count_temp}")

    print(
        f"Portfolio period from days {i+twelve_months} to {i+twelve_months+six_months-1}")
    for p in range(0, no_pairs):
        first_col = index_listed2[pairs[p]['s1_col']]
        second_col = index_listed2[pairs[p]['s2_col']]
        counter = count_temp
        pairs_opened = 0
        new_pairs_opened = 0
        lag = 0
        can_trade = True
        last_operation = 0


        std_limit = np.std(IPt[0:twelve_months, first_col] -
                           IPt[0:twelve_months, second_col])  # standard deviation

        print(f"Std limit: {std_limit}")
        spread = IPt[0:twelve_months, first_col] - IPt[0:twelve_months, second_col]
        #print(f"Spread series: {spread}")

        # Fixed volatility estimated in the 12 months period. Doing the calculation one pair at a time
        # Presets all variables for each pair
        Rcum = np.zeros((twelve_months, 1))
        counter_ret = 1
        Rcum_ret = [1]

        wi = []

        for j in range(i+twelve_months, i+twelve_months+six_months-1):  # portfolio period
            # Defining the period as from the first day of the twe_month to the last day of the twe_month

            """ if Rcum_ret[-1] < 0.85:
                print(f"pair_no {p}")
                print(f"pairs_opened: {pairs_opened}")
                print(f"pair indexes: ({first_col},{second_col})")
                break """

            if daylag == 0:  # w/o one day delay
                if not can_trade:
                    if (last_operation == 1 and (IPt[j-i, first_col]-IPt[j-i, second_col]) <= closing_threshold*std_limit) or (last_operation == -1 and (IPt[j-i, first_col]-IPt[j-i, second_col]) >= -closing_threshold*std_limit):
                        can_trade = True

                if pairs_opened == -1:  # pairs opened: long 1st, short 2nd stock
                    # print("Pair is long on 1st")
                    # If a sign to open has been given, then calcule the returns
                    """ print(f"Weights: w1 {wi[0]} w2 {wi[1]}")
                    print(f"Return indexes {j},{second_col} | Returns r1 {Rt.iloc[j, first_col]} | r2 {Rt.iloc[j, second_col]}")
                    print(f"Calculated return {np.multiply(Rt.iloc[j, first_col], wi[0]) - np.multiply(Rt.iloc[j, second_col], wi[1])}")
                     """
                    Rpair[counter, p] = np.multiply(
                        Rt.iloc[j, first_col], wi[0]) - np.multiply(Rt.iloc[j, second_col], wi[1])
                    # Rpair is the return of each pair.
                    Rcum[counter_ret, 0] = Rpair[counter, p]
                    counter_ret = counter_ret + 1
                    Rcum_ret = np.cumprod(1+Rcum)
                    lag = lag + 1  # used for paying tc

                    if wi_update == 1:  # The weight of each asset in the pair is updated.
                        wi[0] = wi[0]*(1+Rt.iloc[j, first_col])
                        wi[1] = wi[1]*(1+Rt.iloc[j, second_col])

                        # print(f"Updated weights w1 {wi[0]} - w2 {wi[1]}")

                elif pairs_opened == 1:  # pairs opened: short 1st, long 2nd stock
                    # print("Pair is short on 1st")
                    """ print(f"Weights: w1 {wi[0]} w2 {wi[1]}")
                    print(
                        f"Return indexes {j},{second_col} | Returns r1 {Rt.iloc[j, first_col]} - weighted {np.multiply(Rt.iloc[j, first_col], wi[0])} r2 {Rt.iloc[j, second_col]} - weighted {np.multiply(Rt.iloc[j, second_col], wi[1])}")
                    print(
                        f"Calculated return {np.multiply(-Rt.iloc[j, first_col], wi[0]) + np.multiply(Rt.iloc[j, second_col], wi[1])}")
                     """
                    Rpair[counter, p] = np.multiply(
                        -Rt.iloc[j, first_col], wi[0]) + np.multiply(Rt.iloc[j, second_col], wi[1])
                    # print(f"Rpair value {Rpair[counter, p]}")
                    Rcum[counter_ret, 0] = Rpair[counter, p]
                    counter_ret = counter_ret + 1
                    Rcum_ret = np.cumprod(1+Rcum)
                    lag = lag + 1

                    if wi_update == 1:
                        wi[0] = wi[0]*(1+Rt.iloc[j, first_col])
                        wi[1] = wi[1]*(1+Rt.iloc[j, second_col])
                        # print(f"Updated weights w1 {wi[0]} - w2 {wi[1]}")

                else:
                    Rpair[counter, p] = 0  # closed (this code not necessary)

                if ((pairs_opened == 1 and (IPt[j-i, first_col]-IPt[j-i, second_col]) <= closing_threshold*std_limit) or (counter_ret > duration_limit) or (Rcum_ret[-1] < Stop_loss) or (Rcum_ret[-1] >= Stop_gain)
                        or (pairs_opened == -1 and (IPt[j-i, first_col]-IPt[j-i, second_col]) >= -closing_threshold*std_limit)) and ((trade_req + (Vt.iloc[j, first_col] > 0) + (Vt.iloc[j, second_col] > 0)) > 1):
                    #print(f"Closing position {pairs_opened}. Price diff: {IPt[j-i, first_col]-IPt[j-i, second_col]}")
                    
                    converged = True

                    if Rcum_ret[-1] < Stop_loss:
                        Rcum_ret[-1] = Stop_loss
                        converged = False
                        can_trade = False
                        last_operation = pairs_opened

                    if counter_ret > duration_limit:
                        converged = False
                        can_trade = False
                        last_operation = pairs_opened

                    pairs_opened = 0  # close pairs: prices cross
                    # when pair is closed reset lag (it serves for paying tc)
                    lag = 0
                    # add a marker for closing used to calc length of the "open-period"
                    avg_price_dev[counter, no_pairs+p] = 1
                    # Includes trading cost in the last day of trading, due to closing position
                    Rpair[counter, p] = Rpair[counter, p] - percentage_costs

                    print(
                        f"Pair {pairs[p]['s1_ticker']}-{pairs[p]['s2_ticker']} closed. Days: {counter_ret} | Return: {Rcum_ret[-1]}")
                    operations.append({
                        "Semester": big_loop,
                        "Days": counter_ret,
                        "S1": pairs[p]['s1_ticker'],
                        "S2": pairs[p]['s2_ticker'],
                        "Pair": f"{pairs[p]['s1_ticker']}-{pairs[p]['s2_ticker']}",
                        "Return": Rcum_ret[-1],
                        "Converged": converged,
                        "Count day": counter
                    })

                    counter_ret = 1

                elif can_trade and (pairs_opened == 0) and (+IPt[j-i, first_col]-IPt[j-i, second_col] > opening_threshold*std_limit) and ((trade_req + (Vt.iloc[j, first_col] > 0) + (Vt.iloc[j, second_col] > 0)) > 1):
                    #print(f"Opening short position. Price diff: {IPt[j-i, first_col]-IPt[j-i, second_col]} | Threshold: {1.5*std_limit}")
                    if pairs_opened == 0:  # record dev (and time) at open
                        Rcum = np.zeros((six_months, 1))
                        counter_ret = 1
                        avg_price_dev[counter, p] = 2*(+IPt[j-i, first_col] - IPt[j-i, second_col])/(
                            IPt[j-i, first_col] + IPt[j-i, second_col])

                    # print(
                    #    f"Trading short pair {pairs[p]['s1_ticker']}-{pairs[p]['s2_ticker']} on day {j}")
                    pairs_opened = 1  # open pairs
                    lag = lag + 1  # - Lag was 0. On the next loop C will be paid
                    wi = [1, 1]

                elif can_trade and (pairs_opened == 0) and (IPt[j-i, first_col]-IPt[j-i, second_col] < -opening_threshold*std_limit) and ((trade_req + (Vt.iloc[j, first_col] > 0) + (Vt.iloc[j, second_col] > 0)) > 1):
                    #print(f"Opening long position. Price diff: {IPt[j-i, first_col]-IPt[j-i, second_col]} | Threshold: {-1.5*std_limit}")
                    if pairs_opened == 0:  # record dev (and time) at open
                        Rcum = np.zeros((six_months, 1))
                        counter_ret = 1
                        avg_price_dev[counter, p] = 2*(-IPt[j-i, first_col] + IPt[j-i, second_col])/(
                            IPt[j-i, first_col] + IPt[j-i, second_col])
                    # print(
                    #    f"Trading long pair {pairs[p]['s1_ticker']}-{pairs[p]['s2_ticker']} on day {j}")
                    pairs_opened = -1  # open pairs
                    lag = lag + 1
                    wi = [1, 1]

                counter += 1

            elif daylag == 1:
                if pairs_opened == -1:  # pairs opened: long 1st, short 2nd stock
                    Rpair[counter, p] = (+Rt.iloc[j, first_col] * wi[0] -
                                         Rt.iloc[j, second_col] * wi[1]) - (lag == 2)*trading_costs
                    Rcum[counter_ret, 0] = Rpair[counter, p]
                    counter_ret = counter_ret + 1
                    Rcum_ret = np.cumprod(1+Rcum)
                    if wi_update == 1:
                        wi[0] = wi[0]*(1+Rt.iloc[j, first_col])
                        wi[1] = wi[1]*(1+Rt.iloc[j, second_col])

                elif pairs_opened == 1:  # pairs opened: short 1st, long 2nd stock
                    Rpair[counter, p] = (-Rt.iloc[j, first_col] * wi[0] +
                                         Rt.iloc[j, second_col] * wi[1]) - (lag == 2)*trading_costs
                    Rcum[counter_ret, 0] = Rpair[counter, p]
                    counter_ret = counter_ret + 1
                    Rcum_ret = np.cumprod(1+Rcum)
                    if wi_update == 1:
                        wi[0] = wi[0]*(1+Rt.iloc[j, first_col])
                        wi[1] = wi[1]*(1+Rt.iloc[j, second_col])

                else:
                    Rpair[counter, p] = 0  # closed (this code not necessary)

                pairs_opened = new_pairs_opened

                if (pairs_opened == +1 and (IPt[j-i, first_col]-IPt[j-i, second_col]) <= 0
                    or Rcum_ret[-1] <= Stop_loss
                    or (Rcum_ret[-1] >= Stop_gain)
                        or pairs_opened == -1 and (IPt[j-i, first_col]-IPt[j-i, second_col]) >= 0) and ((trade_req + (Vt.iloc[j, first_col] > 0) + (Vt.iloc[j, second_col] > 0)) > 1):

                    new_pairs_opened = 0  # close prices: prices cross
                    # If the pairs are open and the spread is smaller than the
                    # threshold, close the position
                    lag = 0
                    # see above, marker
                    avg_price_dev[counter+1, no_pairs+p] = 1

                    if wi_update == 1:
                        Rpair[counter, p] = Rpair[counter, p] - \
                            trading_costs - percentage_costs

                elif (+IPt[j-i, first_col]-IPt[j-i, second_col] > 2.0*std_limit) and ((trade_req + (Vt.iloc[j, first_col] > 0) + (Vt.iloc[j, second_col] > 0)) > 1):
                    new_pairs_opened = 1  # open pairs
                    # If the difference between the prices are larger than
                    # the limit, and there is volume, open the position (short 1st, long 2nd)
                    lag = lag + 1
                    if pairs_opened == 0:
                        Rcum = np.zeros((six_months, 1))
                        counter_ret = 1

                elif (-IPt[j-i, first_col]+IPt[j-i, second_col] > 2.0*std_limit) and ((trade_req + (Vt.iloc[j, first_col] > 0) + (Vt.iloc[j, second_col] > 0)) > 1):
                    new_pairs_opened = -1  # open pairs
                    # If the difference between the prices are larger than
                    # the limit, and there is volume, open the position (short 2nd, long 1st)
                    lag = lag + 1
                    if pairs_opened == 0:  # - If the pair was closed, reset accumulated return matrix and counter
                        Rcum = np.zeros((six_months, 1))
                        counter_ret = 1

                if new_pairs_opened == +1 and lag == 1:
                    avg_price_dev[counter, p] = 2*(+IPt[j-i, first_col] - IPt[j-i, second_col])/(
                        IPt[j-i, first_col] + IPt[j-i, second_col])
                    lag = lag + 1
                    wi = [1, 1]

                elif new_pairs_opened == -1 and lag == 1:

                    avg_price_dev[counter, p] = 2*(-IPt(j-i, first_col) + IPt(
                        j-i, second_col))/(IPt(j-i, first_col) + IPt(j-i, second_col))
                    lag = lag + 1
                    wi = [1, 1]

                counter += 1

        if pairs_opened != 0:
            print(
                f"Pair {pairs[p]['s1_ticker']}-{pairs[p]['s2_ticker']} did not converged, Days: {counter_ret} | Return: {Rcum_ret[-1]}")
            # Includes trading cost in the last day of trading, due to closing position
            Rpair[counter-1, p] = Rpair[counter-1, p] - \
                trading_costs - percentage_costs
            avg_price_dev[counter-1, no_pairs+p] = 1
            operations.append(
                {
                    "Semester": big_loop,
                    "Days": counter_ret,
                    "S1": pairs[p]['s1_ticker'],
                    "S2": pairs[p]['s2_ticker'],
                    "Pair": f"{pairs[p]['s1_ticker']}-{pairs[p]['s2_ticker']}",
                    "Return": Rcum_ret[-1],
                    "Converged": False,
                    "Count day": counter
                }
            )

    # print(f"Rpair len: {len(Rpair)} | value: {Rpair}")
    pd.DataFrame(Rpair).to_csv("Rpair.csv", header=None, index=False)

    # Using 2 Weighting Schemes - Fully Invested and Committed Capital
    # ------------------------------------------------------------
    # Calculate portfolio returns (ew, vw) out of percentage Rpair
    # ------------------------------------------------------------

    print(f"Calculating returns from day {counter-six_months+1} to {counter}")

    Rpair_temp = Rpair[counter-six_months+1:counter+1]
    # Ret_acum = np.zeros((six_months, 4))
    #
    # eq-weighted average on committed cap.; weights reset to "one" (or any equal weight) after each day
    #
    wi = np.ones((1, no_pairs))
    np.append(wi, np.cumprod(1+Rpair_temp))
    # print(f"Wi shape: {np.shape(wi)}")

    #
    # ew-weighted, committed cap.; weights "restart" every 6 month period;
    # (each portfolio gets 1 dollar at the beginning)
    # print(f"Rpair_temp len: {np.shape(Rpair_temp)} value: {Rpair_temp}")

    pd.DataFrame(Rpair_temp[:six_months]).to_csv(
        "rpair_limited.csv", header=None, index=False, na_rep='NULL')
    pd.DataFrame(np.sum(np.multiply(wi, Rpair_temp[:six_months]), axis=1)).to_csv(
        "row_sum.csv", header=None, index=False)
    Rp_ew_cc['Return'][counter-six_months+1:counter+1] = np.nansum(
        np.multiply(wi, Rpair_temp[:six_months]), axis=1) / np.sum(wi)

    # print(f"Rp_ew_cc len: {np.shape(Rp_ew_cc)} | value: {Rp_ew_cc}")

    ret_acum_df['CC'][counter-six_months+1:counter+1] = np.cumprod(
        1 + (Rp_ew_cc['Return'][counter-six_months+1:counter+1]))[:six_months]
    # [MaxDD,~] = maxdrawdown(ret2tick(Rp_ew_cc(counter-Six_mo:counter-1,:)));
    # MDDw(big_loop,2) = MaxDD;
    # Sortino = sortinoratio(Rp_ew_cc(counter-Six_mo:counter-1,:),0);
    # Sortino_w(big_loop,2) = Sortino;

    #
    # vw-weighted, fully invested; weights "restart" from 1 every time a new pair is opened;
    # Capital divided between open portfolios.

    pd.DataFrame(avg_price_dev).to_csv(
        "avg_price_dev.csv", header=None, index=False)

    # indicator for days when pairs open
    pa_open = np.zeros((six_months, no_pairs))
    for i2 in range(0, no_pairs):
        pa_opened_temp = 0
        temp_lag = 0

        for i1 in range(0, six_months):
            if pa_opened_temp == 1 and daylag == 0:  # opening period not included, closing included
                pa_open[i1, i2] = 1
                days_open[pairs_number, 0] = days_open[pairs_number, 0] + 1

            if pa_opened_temp == 1 and daylag == 1 and temp_lag == 1:
                pa_open[i1, i2] = 1
                days_open[pairs_number, 0] = days_open[pairs_number, 0] + 1

            if pa_opened_temp == 1 and daylag == 1 and temp_lag == 0:
                temp_lag = 1

            if avg_price_dev[counter-six_months+i1+1, i2] != 0:
                pa_opened_temp = 1
                pairs_number = pairs_number + 1

            if avg_price_dev[counter-six_months+i1+1, no_pairs+i2] != 0:
                pa_opened_temp = 0
                temp_lag = 0

    # pd.DataFrame(pa_open).to_csv("pa_open.csv", header=None, index=False)

    wi2 = np.multiply(wi, pa_open)

    for i2 in range(0, six_months):  # takes care in a situation where no pairs are open
        if sum(pa_open[i2, :]) == 0:
            wi2[i2, 0:no_pairs] = 0.2 * np.ones((1, no_pairs))
            pa_open[i2, 0:no_pairs] = np.ones((1, no_pairs))

    # pd.DataFrame(wi2).to_csv("wi2.csv", header=None, index=False)

    Rp_vw_fi['Return'][counter-six_months+1:counter+1] = np.divide(np.nansum(np.multiply(
        wi2, Rpair_temp[:six_months+1, :]), axis=1), np.sum(wi2, axis=1))

    ret_acum_df['FI'][counter-six_months+1:counter +
                      1] = np.cumprod(1+(Rp_vw_fi['Return'][counter-six_months+1:counter+1]))
    # [MaxDD,~] = maxdrawdown(ret2tick(Rp_vw_fi(counter-Six_mo:counter-1,:)));
    # MDDw(big_loop,4) = MaxDD;
    # Sortino = sortinoratio(Rp_vw_fi(counter-Six_mo:counter-1,:),0);
    # Sortino_w(big_loop,4) = Sortino;

    RmRf[counter-six_months+1:counter +
                   1] = (Rm.iloc[counter-six_months+1:counter + 1, :] - Rf.iloc[counter-six_months+1:counter + 1, :]).to_numpy()

    risk_free['Return'][counter-six_months+1:counter + 1] = (Rf.iloc[counter-six_months+1:counter + 1, 0])

    ret_acum_df['RMRF'][counter-six_months+1:counter+1] = np.cumprod(
        1+(Rm.iloc[:six_months, 0]-Rf.iloc[:six_months, 0]).to_numpy())

    ret_acum_df['SEMESTER'][counter-six_months+1:counter+1] = int(big_loop)
    Rp_ew_cc['Semester'][counter-six_months+1:counter+1] = int(big_loop)
    Rp_vw_fi['Semester'][counter-six_months+1:counter+1] = int(big_loop)
    risk_free['Semester'][counter-six_months+1:counter+1] = int(big_loop)

    if Stop_loss == float("-inf"):
        Rp_ew_cc.to_csv("../hurst_results/Rp_ew_cc.csv", index=False)
        Rp_vw_fi.to_csv("../hurst_results/Rp_vw_fi.csv", index=False)
        pd.DataFrame(RmRf).to_csv("../hurst_results/RmRf.csv", header=None, index=False)
        risk_free.to_csv("../hurst_results/risk_free.csv")
        ret_acum_df.to_csv("../hurst_results/ret_acum_df.csv")
    else:
        Rp_ew_cc.to_csv(f"../hurst_results/Rp_ew_cc.csv", index=False)
        Rp_vw_fi.to_csv(f"../hurst_results/Rp_vw_fi.csv", index=False)
        pd.DataFrame(RmRf).to_csv(f"../hurst_results/RmRf.csv", header=None, index=False)
        risk_free.to_csv(f"../hurst_results/risk_free.csv")
        ret_acum_df.to_csv(f"../hurst_results/ret_acum_df.csv")

    for i2 in range(0, no_pairs):
        if sum(avg_price_dev[counter-six_months+1:counter+1, i2] != 0) != 0:
            periods_with_open_pair = periods_with_open_pair + 1
            no_pairs_opened[big_loop, i2] = no_pairs_opened[
                big_loop, p] + sum(avg_price_dev[counter-six_months+1:counter+1, i2] != 0)
        else:
            periods_without_open_pair = periods_without_open_pair + 1

    
    i = i + periods.iloc[big_loop, 0]

    big_loop = big_loop + 1

operations_df = pd.DataFrame(operations)
if Stop_loss == float('-inf'):
    operations_df.to_csv(f"../hurst_results/duration_limit/operations.csv")
else:
    operations_df.to_csv(f"../hurst_results/operations.csv")

##################################################################
# FINAL ANALYSIS AND CHART GENERATION
##################################################################

print("\n\n========================================================")
print("           FINAL PORTFOLIO ANALYSIS")
print("========================================================")

# --- Define Helper Functions for Performance Metrics ---

def calculate_sortino_ratio(returns, risk_free_rate=0):
    """Calculates the Sortino Ratio."""
    target_return = 0
    downside_returns = returns[returns < target_return]
    if len(downside_returns) == 0:
        return np.nan
    expected_return = returns.mean()
    downside_std = downside_returns.std()
    sortino = (expected_return - risk_free_rate) / downside_std
    return sortino * np.sqrt(252) # Annualize

def calculate_max_drawdown(returns):
    """Calculates the Maximum Drawdown."""
    cumulative_returns = (1 + returns).cumprod()
    peak = cumulative_returns.expanding(min_periods=1).max()
    drawdown = (cumulative_returns - peak) / peak
    return drawdown.min()

# --- Part 1: Generate Data for "Descriptive Statistics" Table ---

print("\n--- Descriptive Statistics for the Most Traded Assets (Table 2) ---")

# Define how many top assets to analyze
top_n_assets = 11 
most_common_assets = asset_frequency_counter.most_common(top_n_assets)

stats_data = []
for asset_ticker, count in most_common_assets:
    # Get the full return series for the asset
    asset_returns = Rt[asset_ticker].dropna()
    
    # Calculate stats
    mean_ret = asset_returns.mean()
    std_dev = asset_returns.std()
    sharpe_ratio = (mean_ret / std_dev) * np.sqrt(252) # Assuming Rf=0 for individual asset SR
    min_ret = asset_returns.min()
    max_ret = asset_returns.max()
    
    stats_data.append({
        "Symbol": asset_ticker,
        "Mean": f"{mean_ret:.4f}",
        "Std Dev": f"{std_dev:.4f}",
        "SR": f"{sharpe_ratio:.4f}",
        "Min": f"{min_ret*100:.2f}",
        "Max": f"{max_ret*100:.2f}"
    })

stats_df = pd.DataFrame(stats_data)
print(stats_df.to_string(index=False))

stats_df.to_csv(f"../hurst_results/final_analysis_stats.csv")

# --- Part 2: Generate Data for "Excess Returns" Table ---

print("\n\n--- Performance Metrics of Trading Strategies (Table 3) ---")

# Consolidate the portfolio returns, dropping any non-trading periods
cc_returns = Rp_ew_cc[Rp_ew_cc['Return'] != 0]['Return'].dropna()
fi_returns = Rp_vw_fi[Rp_vw_fi['Return'] != 0]['Return'].dropna()
rf_returns = risk_free[risk_free.index.isin(cc_returns.index)]['Return'].dropna()

# Align risk-free rates with portfolio returns
cc_excess_returns = cc_returns - rf_returns
fi_excess_returns = fi_returns - rf_returns

# Calculate metrics for both strategies
metrics = {}
strategies = {
    "Committed Capital": (cc_returns, cc_excess_returns),
    "Fully Invested": (fi_returns, fi_excess_returns)
}

for name, (returns, excess_returns) in strategies.items():
    if len(returns) > 0:
        # Annualized values
        ann_mean_return = returns.mean() * 252
        ann_std_dev = returns.std() * np.sqrt(252)
        ann_sharpe_ratio = (excess_returns.mean() * 252) / ann_std_dev
        
        metrics[name] = {
            "Mean Return (%)": f"{ann_mean_return * 100:.3f}",
            "Sharpe Ratio": f"{ann_sharpe_ratio:.3f}",
            "Sortino Ratio": f"{calculate_sortino_ratio(returns, rf_returns.mean()):.3f}",
            "t-statistic": f"{scipy.stats.ttest_1samp(returns, 0).statistic:.3f}",
            "% of negative excess returns": f"{ (excess_returns < 0).sum() / len(excess_returns) * 100:.2f}",
            "MDD (%)": f"{calculate_max_drawdown(returns) * 100:.2f}",
            "Annualized STD (%)": f"{ann_std_dev * 100:.3f}",
            "Skewness": f"{returns.skew():.3f}",
            "Kurtosis": f"{returns.kurtosis():.3f}", # Pandas kurtosis is excess kurtosis (0 is normal)
            "Minimum Daily Ret (%)": f"{returns.min() * 100:.3f}",
            "Maximum Daily Ret (%)": f"{returns.max() * 100:.3f}"
        }
    else:
        metrics[name] = {k: "N/A" for k in strategies["Committed Capital"][1]}


performance_df = pd.DataFrame(metrics)
print(performance_df)

performance_df.to_csv(f"../hurst_results/final_analysis_performance.csv")

# --------------------
# Generating chart
# --------------------

print("\n--- Generating Cumulative Excess Returns Plot ---")

# We will plot only the "Committed Capital" strategy returns.
# First, get the series of non-zero daily returns for this strategy.
cc_returns = Rp_ew_cc[Rp_ew_cc['Return'] != 0]['Return'].dropna()

# Get the corresponding risk-free rates for the same days
if not cc_returns.empty:
    rf_returns = risk_free.loc[cc_returns.index, 'Return'].dropna()

    # Calculate the excess returns
    cc_excess_returns = cc_returns - rf_returns

    # Calculate the cumulative product of the excess returns
    cumulative_cc = (1 + cc_excess_returns).cumprod()

    # Use a simple numerical series (0, 1, 2, ...) for the x-axis
    x_axis_data = range(len(cumulative_cc))

    # --- Create the plot ---
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, ax = plt.subplots(figsize=(14, 8))

    ax.plot(x_axis_data, cumulative_cc, label='Committed Capital', linewidth=2, color='C0') # 'C0' is default blue

    # Add titles and labels for clarity
    ax.set_title('Cumulative Excess Returns (Committed Capital)', fontsize=16)
    ax.set_xlabel('Trading Days', fontsize=12)
    ax.set_ylabel('Cumulative Excess Returns', fontsize=12)
    ax.legend(fontsize=12)

    # Set a baseline at 1.0 for reference
    ax.axhline(y=1, color='grey', linestyle='--', linewidth=1)
    
    print("Displaying plot...")
    plt.show()

else:
    print("No trading data available to generate the plot.")

print("\n========================================================")
print("                 ANALYSIS COMPLETE")
print("========================================================")
# Out:
# Days: 6425 | Assets: 1100
#
# ================ Period 0 ================
# Formation Period: 252 days | Trading Period: 128 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:25<00:00, 42.52it/s]
# Number of listed stocks in period: 482
# Period 0
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 481/481 [00:01<00:00, 375.50it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:53<00:00,  9.35it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1262
#  2. Pair:     AXP-VAT     | Hurst: 0.2389
#  3. Pair:     DOV-FJ      | Hurst: 0.2408
#  4. Pair:     IFF-WLA     | Hurst: 0.2416
#  5. Pair:     DOW-NYT     | Hurst: 0.2460
#  6. Pair:     MAS-CVS     | Hurst: 0.2538
#  7. Pair:     PEP-1028411Q | Hurst: 0.2556
#  8. Pair:   1680Q-TIN     | Hurst: 0.2588
#  9. Pair:     PEP-THY     | Hurst: 0.2615
# 10. Pair:     CAT-WMX     | Hurst: 0.2625
# ------------------------------------------------------------------
#
# counter value: 0 | counter_temp = 0
# Portfolio period from days 252 to 379
# Std limit: 3.0474365953173455e-05
# Pair JCI-1436513D closed. Days: 33 | Return: 1.0000339721296883
# Pair JCI-1436513D closed. Days: 13 | Return: 1.000067053695677
# Pair JCI-1436513D closed. Days: 28 | Return: 1.0000880773032392
# Pair JCI-1436513D closed. Days: 9 | Return: 1.0000487634419453
# Pair JCI-1436513D closed. Days: 17 | Return: 1.0000517140747271
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000496473936427
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000530726014745
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000530720456642
# Pair JCI-1436513D closed. Days: 8 | Return: 1.0000303561700472
# Std limit: 0.03980555313009351
# Pair AXP-VAT closed. Days: 7 | Return: 0.95
# Pair AXP-VAT closed. Days: 3 | Return: 0.95
# Std limit: 0.03712865348318639
# Pair DOV-FJ closed. Days: 6 | Return: 1.0561653534215103
# Pair DOV-FJ closed. Days: 6 | Return: 0.95
# Std limit: 0.029615781908398628
# Pair IFF-WLA closed. Days: 3 | Return: 0.95
# Std limit: 0.037292947959065535
# Pair DOW-NYT closed. Days: 2 | Return: 1.0311973864416943
# Pair DOW-NYT closed. Days: 21 | Return: 1.040545653729688
# Pair DOW-NYT closed. Days: 12 | Return: 1.0316708116159037
# Pair DOW-NYT closed. Days: 7 | Return: 0.95
# Pair DOW-NYT closed. Days: 6 | Return: 1.105111093701688
# Std limit: 0.03561385110291789
# Pair MAS-CVS closed. Days: 10 | Return: 1.0378063523521592
# Pair MAS-CVS closed. Days: 19 | Return: 1.0412765601711729
# Pair MAS-CVS closed. Days: 25 | Return: 0.95
# Pair MAS-CVS closed. Days: 13 | Return: 0.95
# Std limit: 0.03770508214096606
# Pair PEP-1028411Q closed. Days: 7 | Return: 0.95
# Std limit: 0.04074555439144739
# Pair 1680Q-TIN closed. Days: 12 | Return: 0.95
# Std limit: 0.04961133343254633
# Pair PEP-THY closed. Days: 4 | Return: 0.95
# Pair PEP-THY closed. Days: 17 | Return: 0.95
# Std limit: 0.03823859120103985
# Pair CAT-WMX closed. Days: 4 | Return: 1.0476194847837101
# Pair CAT-WMX closed. Days: 24 | Return: 1.0653927487557353
# Pair CAT-WMX closed. Days: 20 | Return: 1.0761989505750944
# Pair CAT-WMX closed. Days: 3 | Return: 0.95
# Calculating returns from day 0 to 127
#
# ================ Period 1 ================
# Formation Period: 253 days | Trading Period: 126 days
# Generating Assets Price Index
# /tmp/ipykernel_29436/3732225093.py:191: RuntimeWarning: invalid value encountered in scalar multiply17<00:15, 30.90it/s]
#   IPt[i2, j] = IPt[i2-1, j] * (1 + Rt.iloc[i+i2, j])
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:23<00:00, 46.99it/s]
# Number of listed stocks in period: 488
# Period 1
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 487/487 [00:01<00:00, 348.92it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:31<00:00, 16.12it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1251
#  2. Pair:     AVY-CINL    | Hurst: 0.2520
#  3. Pair: 300583Q-8375930Q | Hurst: 0.2530
#  4. Pair:      GE-MAS     | Hurst: 0.2565
#  5. Pair:     PPW-PEG     | Hurst: 0.2604
#  6. Pair:    TGNA-1356Q   | Hurst: 0.2660
#  7. Pair:   1530Q-CAT     | Hurst: 0.2670
#  8. Pair:     ABT-BOL     | Hurst: 0.2707
#  9. Pair:     NAE-334702Q | Hurst: 0.2724
# 10. Pair:      FL-1166Q   | Hurst: 0.2725
# ------------------------------------------------------------------
#
# counter value: 127 | counter_temp = 127
# Portfolio period from days 380 to 505
# Std limit: 3.3031880565138366e-05
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000786378508644
# Pair JCI-1436513D closed. Days: 32 | Return: 1.0000616724447267
# Pair JCI-1436513D closed. Days: 15 | Return: 1.000032219174004
# Pair JCI-1436513D closed. Days: 63 | Return: 1.000035465152786
# Pair JCI-1436513D did not converged, Days: 7 | Return: 0.9999536509536028
# Std limit: 0.045992803234648105
# Pair AVY-CINL closed. Days: 2 | Return: 1.0381664750351214
# Pair AVY-CINL closed. Days: 9 | Return: 1.0816549103893658
# Pair AVY-CINL closed. Days: 5 | Return: 1.04691749805938
# Pair AVY-CINL closed. Days: 40 | Return: 0.95
# Pair AVY-CINL closed. Days: 3 | Return: 1.041521157449775
# Std limit: 0.024372782717885014
# Pair 300583Q-8375930Q closed. Days: 53 | Return: 0.95
# Std limit: 0.04581846520976651
# Pair GE-MAS closed. Days: 2 | Return: 1.0328907196380737
# Pair GE-MAS closed. Days: 36 | Return: 0.95
# Std limit: 0.025810987568819627
# Pair PPW-PEG closed. Days: 3 | Return: 1.0307466232264177
# Pair PPW-PEG closed. Days: 4 | Return: 1.0220428445233545
# Pair PPW-PEG closed. Days: 15 | Return: 1.0232599330165277
# Pair PPW-PEG closed. Days: 3 | Return: 1.0244665339526813
# Pair PPW-PEG closed. Days: 3 | Return: 1.025343101947135
# Std limit: 0.052536137237291086
# Pair TGNA-1356Q closed. Days: 13 | Return: 0.95
# Std limit: 0.0472890260018234
# Pair 1530Q-CAT closed. Days: 16 | Return: 1.0881221544972772
# Pair 1530Q-CAT closed. Days: 15 | Return: 1.0480109216089428
# Pair 1530Q-CAT closed. Days: 7 | Return: 0.95
# Std limit: 0.04704638576939471
# Std limit: 0.03276473118784877
# Pair NAE-334702Q closed. Days: 11 | Return: 0.95
# Std limit: 0.05004454510273748
# Pair FL-1166Q closed. Days: 4 | Return: 0.95
# Pair FL-1166Q closed. Days: 5 | Return: 1.083969889308219
# Pair FL-1166Q closed. Days: 14 | Return: 1.1033407651241012
# Pair FL-1166Q closed. Days: 5 | Return: 1.046409782526426
# Pair FL-1166Q closed. Days: 6 | Return: 0.95
# Pair FL-1166Q closed. Days: 19 | Return: 1.0695932111079498
# Pair FL-1166Q closed. Days: 3 | Return: 0.95
# Pair FL-1166Q did not converged, Days: 2 | Return: 1.005778672567212
# Calculating returns from day 127 to 252
#
# ================ Period 2 ================
# Formation Period: 254 days | Trading Period: 128 days
# Generating Assets Price Index
# /tmp/ipykernel_29436/3732225093.py:191: RuntimeWarning: invalid value encountered in scalar multiply17<00:08, 47.28it/s]
#   IPt[i2, j] = IPt[i2-1, j] * (1 + Rt.iloc[i+i2, j])
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:21<00:00, 50.60it/s]
# Number of listed stocks in period: 492
# Period 2
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 491/491 [00:01<00:00, 374.21it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:39<00:00, 12.60it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1367
#  2. Pair: 3393199Q-2254Q   | Hurst: 0.2457
#  3. Pair: 544791Q-PAS     | Hurst: 0.2503
#  4. Pair:     SKY-PAS     | Hurst: 0.2540
#  5. Pair:     DOW-0910150D | Hurst: 0.2544
#  6. Pair:     CEG-PPW     | Hurst: 0.2560
#  7. Pair:      GE-PAS     | Hurst: 0.2567
#  8. Pair:     BAC-APD     | Hurst: 0.2582
#  9. Pair:     BLS-3054Q   | Hurst: 0.2589
# 10. Pair: 677004Q-300583Q | Hurst: 0.2593
# ------------------------------------------------------------------
#
# counter value: 252 | counter_temp = 252
# Portfolio period from days 506 to 633
# Std limit: 2.471252402779951e-05
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000724187309529
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000649953668557
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000502244192881
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000836334106096
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000359944998127
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000290025927048
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000031882020646
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000510805622753
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000341439329694
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000490757248175
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000354358552936
# Pair JCI-1436513D closed. Days: 9 | Return: 1.000050387145247
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000459263569839
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000304166746086
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000150613689591
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000468222571
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000469152395184
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000516853295354
# Pair JCI-1436513D closed. Days: 4 | Return: 1.000031276665597
# Std limit: 0.029471486737934285
# Pair 3393199Q-2254Q closed. Days: 4 | Return: 1.0313088174890566
# Pair 3393199Q-2254Q closed. Days: 8 | Return: 1.0223383995102187
# Pair 3393199Q-2254Q closed. Days: 24 | Return: 1.082988264336234
# Pair 3393199Q-2254Q closed. Days: 28 | Return: 1.0203352862127057
# Pair 3393199Q-2254Q did not converged, Days: 12 | Return: 1.0372394114518582
# Std limit: 0.04960812517548324
# Pair 544791Q-PAS closed. Days: 24 | Return: 0.95
# Pair 544791Q-PAS closed. Days: 22 | Return: 1.033722807186024
# Std limit: 0.045433846461510635
# Pair SKY-PAS closed. Days: 2 | Return: 0.95
# Std limit: 0.032234248817806774
# Pair DOW-0910150D closed. Days: 18 | Return: 1.0698241175637124
# Pair DOW-0910150D closed. Days: 6 | Return: 1.038203657480767
# Pair DOW-0910150D closed. Days: 2 | Return: 1.0437726705869872
# Pair DOW-0910150D closed. Days: 5 | Return: 1.0389978040734855
# Pair DOW-0910150D closed. Days: 4 | Return: 1.031092589588959
# Pair DOW-0910150D closed. Days: 4 | Return: 1.0325831625150874
# Pair DOW-0910150D closed. Days: 8 | Return: 1.0313400005926274
# Pair DOW-0910150D did not converged, Days: 17 | Return: 0.985226977943356
# Std limit: 0.032460047811113335
# Pair CEG-PPW closed. Days: 19 | Return: 0.95
# Std limit: 0.040696634077003406
# Pair GE-PAS closed. Days: 6 | Return: 1.0810723663246793
# Pair GE-PAS closed. Days: 12 | Return: 1.0298521991576444
# Pair GE-PAS closed. Days: 14 | Return: 0.95
# Pair GE-PAS did not converged, Days: 8 | Return: 1.0288042913428193
# Std limit: 0.04417375576787808
# Pair BAC-APD closed. Days: 17 | Return: 1.0940735499174628
# Pair BAC-APD closed. Days: 11 | Return: 1.0423671198482225
# Pair BAC-APD closed. Days: 52 | Return: 1.0291928475363694
# Pair BAC-APD closed. Days: 3 | Return: 1.0671091708445846
# Pair BAC-APD did not converged, Days: 9 | Return: 0.999494264920895
# Std limit: 0.019003927317779543
# Pair BLS-3054Q closed. Days: 5 | Return: 1.0320829351021998
# Pair BLS-3054Q closed. Days: 19 | Return: 1.0506180945271828
# Pair BLS-3054Q closed. Days: 5 | Return: 1.0131135386491452
# Pair BLS-3054Q closed. Days: 20 | Return: 1.031037182454719
# Pair BLS-3054Q closed. Days: 4 | Return: 1.0202890400505635
# Pair BLS-3054Q closed. Days: 14 | Return: 0.95
# Std limit: 0.030045212995577025
# Calculating returns from day 252 to 379
#
# ================ Period 3 ================
# Formation Period: 254 days | Trading Period: 124 days
# Generating Assets Price Index
# /tmp/ipykernel_29436/3732225093.py:191: RuntimeWarning: invalid value encountered in scalar multiply22<00:09, 39.74it/s]
#   IPt[i2, j] = IPt[i2-1, j] * (1 + Rt.iloc[i+i2, j])
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:30<00:00, 35.74it/s]
# Number of listed stocks in period: 491
# Period 3
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 490/490 [00:01<00:00, 405.94it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:36<00:00, 13.64it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1397
#  2. Pair:     AEP-NEE     | Hurst: 0.2513
#  3. Pair:     XEL-TXU     | Hurst: 0.2582
#  4. Pair:     KMB-CSX     | Hurst: 0.2593
#  5. Pair:     EXC-SYY     | Hurst: 0.2596
#  6. Pair:     PNC-FBF     | Hurst: 0.2619
#  7. Pair:     TRB-ADP     | Hurst: 0.2666
#  8. Pair:     SHW-544791Q | Hurst: 0.2667
#  9. Pair:     MCD-FBF     | Hurst: 0.2718
# 10. Pair:       T-USW     | Hurst: 0.2793
# ------------------------------------------------------------------
#
# counter value: 379 | counter_temp = 379
# Portfolio period from days 634 to 757
# Std limit: 2.3674033550732475e-05
# Pair JCI-1436513D closed. Days: 23 | Return: 1.0000264531221588
# Pair JCI-1436513D closed. Days: 8 | Return: 1.000037608122989
# Pair JCI-1436513D closed. Days: 12 | Return: 1.0000212590116202
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000528801745152
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000263766634563
# Pair JCI-1436513D closed. Days: 33 | Return: 1.000026372101807
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000448925235228
# Pair JCI-1436513D closed. Days: 9 | Return: 1.0000487664153366
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000496889407868
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000289431281861
# Pair JCI-1436513D closed. Days: 10 | Return: 1.0000215884116201
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000222044617333
# Pair JCI-1436513D did not converged, Days: 1 | Return: 1.0000222044617333
# Std limit: 0.016477431097341025
# Pair AEP-NEE closed. Days: 16 | Return: 1.0151224824331189
# Pair AEP-NEE closed. Days: 4 | Return: 1.017959079662797
# Pair AEP-NEE closed. Days: 20 | Return: 0.95
# Pair AEP-NEE did not converged, Days: 20 | Return: 0.9543632036351639
# Std limit: 0.015685796246668045
# Pair XEL-TXU closed. Days: 9 | Return: 1.0202024594145083
# Pair XEL-TXU closed. Days: 29 | Return: 1.027328807423356
# Pair XEL-TXU closed. Days: 32 | Return: 0.95
# Std limit: 0.03882989061573146
# Pair KMB-CSX closed. Days: 17 | Return: 0.95
# Std limit: 0.03372753901683755
# Pair EXC-SYY closed. Days: 7 | Return: 1.0908449183367912
# Pair EXC-SYY closed. Days: 12 | Return: 1.0836017467649712
# Pair EXC-SYY closed. Days: 7 | Return: 0.95
# Std limit: 0.034587575314631185
# Pair PNC-FBF closed. Days: 3 | Return: 1.0515537526615004
# Pair PNC-FBF closed. Days: 29 | Return: 1.034470911731423
# Pair PNC-FBF closed. Days: 2 | Return: 1.0324274567053595
# Pair PNC-FBF closed. Days: 5 | Return: 0.95
# Std limit: 0.032689115068679886
# Pair TRB-ADP closed. Days: 13 | Return: 1.0337979160802795
# Pair TRB-ADP closed. Days: 3 | Return: 1.0404608601854275
# Pair TRB-ADP closed. Days: 10 | Return: 0.95
# Std limit: 0.038602404824689816
# Pair SHW-544791Q closed. Days: 2 | Return: 1.0620335908937908
# Pair SHW-544791Q closed. Days: 7 | Return: 1.0456407220031851
# Pair SHW-544791Q closed. Days: 5 | Return: 1.0356987191441607
# Pair SHW-544791Q closed. Days: 8 | Return: 1.0433169491134653
# Pair SHW-544791Q closed. Days: 5 | Return: 0.95
# Std limit: 0.04204575293444125
# Pair MCD-FBF closed. Days: 6 | Return: 1.051238375327754
# Pair MCD-FBF closed. Days: 3 | Return: 0.95
# Pair MCD-FBF closed. Days: 5 | Return: 0.95
# Pair MCD-FBF closed. Days: 9 | Return: 1.0337293864605086
# Pair MCD-FBF closed. Days: 4 | Return: 0.95
# Pair MCD-FBF did not converged, Days: 1 | Return: 0.95
# Std limit: 0.035753195473050656
# Pair T-USW closed. Days: 23 | Return: 1.0951249980540811
# Pair T-USW closed. Days: 34 | Return: 1.0296394942076748
# Calculating returns from day 379 to 502
#
# ================ Period 4 ================
# Formation Period: 252 days | Trading Period: 128 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:23<00:00, 47.23it/s]
# Number of listed stocks in period: 489
# Period 4
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 488/488 [00:01<00:00, 452.65it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:36<00:00, 13.89it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1196
#  2. Pair:     ABT-BMY     | Hurst: 0.2660
#  3. Pair:     NMK-3891289Q | Hurst: 0.2660
#  4. Pair:     NEU-RHDCQ   | Hurst: 0.2673
#  5. Pair:     SHW-PCAR    | Hurst: 0.2695
#  6. Pair:     MMM-CNRG    | Hurst: 0.2737
#  7. Pair:     XOM-677004Q | Hurst: 0.2740
#  8. Pair:     TRB-WY      | Hurst: 0.2742
#  9. Pair: 300583Q-TNB     | Hurst: 0.2760
# 10. Pair:   1463Q-1281683D | Hurst: 0.2764
# ------------------------------------------------------------------
#
# counter value: 502 | counter_temp = 502
# Portfolio period from days 758 to 885
# Std limit: 2.221796112085273e-05
# Pair JCI-1436513D closed. Days: 62 | Return: 1.0000454765027456
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000171072158277
# Pair JCI-1436513D closed. Days: 8 | Return: 1.000032708067888
# Pair JCI-1436513D closed. Days: 21 | Return: 1.0000467111259639
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000475650733385
# Pair JCI-1436513D did not converged, Days: 27 | Return: 0.9999936761085368
# Std limit: 0.02667058818665896
# Pair ABT-BMY closed. Days: 10 | Return: 1.0339698427889876
# Pair ABT-BMY closed. Days: 5 | Return: 1.0320300968083205
# Pair ABT-BMY closed. Days: 14 | Return: 1.0280539681407124
# Pair ABT-BMY did not converged, Days: 26 | Return: 0.9549589442744043
# Std limit: 0.030264384721400698
# Pair NMK-3891289Q closed. Days: 9 | Return: 0.95
# Pair NMK-3891289Q closed. Days: 14 | Return: 1.0426209512311748
# Pair NMK-3891289Q closed. Days: 9 | Return: 0.95
# Std limit: 0.03795974776683526
# Pair NEU-RHDCQ closed. Days: 13 | Return: 0.95
# Std limit: 0.03405700142297116
# Pair SHW-PCAR closed. Days: 9 | Return: 1.071711443309877
# Pair SHW-PCAR closed. Days: 9 | Return: 0.95
# Pair SHW-PCAR closed. Days: 3 | Return: 1.0290733201104714
# Pair SHW-PCAR closed. Days: 4 | Return: 1.0348698816597872
# Pair SHW-PCAR closed. Days: 10 | Return: 1.02508558663768
# Pair SHW-PCAR closed. Days: 8 | Return: 0.95
# Std limit: 0.032587338201213116
# Pair MMM-CNRG closed. Days: 9 | Return: 1.0748817383598506
# Pair MMM-CNRG closed. Days: 14 | Return: 0.95
# Pair MMM-CNRG closed. Days: 19 | Return: 0.95
# Std limit: 0.023052987860730758
# Std limit: 0.0436773092450104
# Pair TRB-WY closed. Days: 7 | Return: 1.0350737014016833
# Pair TRB-WY closed. Days: 6 | Return: 1.0425445983330184
# Pair TRB-WY closed. Days: 8 | Return: 1.0479949753904245
# Pair TRB-WY closed. Days: 5 | Return: 1.0467959237649218
# Pair TRB-WY closed. Days: 6 | Return: 1.0801987900906418
# Pair TRB-WY closed. Days: 3 | Return: 0.95
# Pair TRB-WY closed. Days: 7 | Return: 1.0569232405795617
# Pair TRB-WY closed. Days: 13 | Return: 0.95
# Std limit: 0.02852092954290305
# Pair 300583Q-TNB closed. Days: 36 | Return: 1.0381321154220444
# Pair 300583Q-TNB closed. Days: 35 | Return: 1.0273144374571979
# Pair 300583Q-TNB closed. Days: 5 | Return: 1.022151216425974
# Std limit: 0.03728923184504057
# Pair 1463Q-1281683D closed. Days: 20 | Return: 0.95
# Calculating returns from day 502 to 629
#
# ================ Period 5 ================
# Formation Period: 252 days | Trading Period: 125 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:22<00:00, 48.00it/s]
# Number of listed stocks in period: 488
# Period 5
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 487/487 [00:01<00:00, 424.10it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:35<00:00, 14.26it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1212
#  2. Pair:     WLA-300583Q | Hurst: 0.2265
#  3. Pair:     HSH-2254Q   | Hurst: 0.2525
#  4. Pair:     RTN-1513Q   | Hurst: 0.2611
#  5. Pair: 2269312Q-USB     | Hurst: 0.2635
#  6. Pair:     ABT-BMY     | Hurst: 0.2637
#  7. Pair: 162007Q-TOY     | Hurst: 0.2656
#  8. Pair: 1005945D-ED      | Hurst: 0.2659
#  9. Pair:     LDG-VVI     | Hurst: 0.2687
# 10. Pair:    SPXC-VVI     | Hurst: 0.2732
# ------------------------------------------------------------------
#
# counter value: 629 | counter_temp = 629
# Portfolio period from days 886 to 1010
# Std limit: 1.7779582438756645e-05
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000389360532294
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000366658647193
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000297561051106
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000229541626338
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000038912474005
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000242472633623
# Pair JCI-1436513D closed. Days: 4 | Return: 1.000036524533496
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000397992577523
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000270881579962
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000372627764045
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000023183141697
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000331013198966
# Pair JCI-1436513D did not converged, Days: 3 | Return: 1.000015746067662
# Std limit: 0.04056745886190947
# Pair WLA-300583Q closed. Days: 6 | Return: 1.0476982558473724
# Pair WLA-300583Q closed. Days: 11 | Return: 1.0530371004544161
# Pair WLA-300583Q closed. Days: 15 | Return: 0.95
# Std limit: 0.03309063373391627
# Std limit: 0.03664007429979104
# Pair RTN-1513Q closed. Days: 4 | Return: 1.0359795599632347
# Pair RTN-1513Q closed. Days: 17 | Return: 0.95
# Pair RTN-1513Q closed. Days: 8 | Return: 1.046034489322593
# Pair RTN-1513Q did not converged, Days: 21 | Return: 1.0127464080242627
# Std limit: 0.03667717374094746
# Pair 2269312Q-USB closed. Days: 15 | Return: 1.0320840559233233
# Pair 2269312Q-USB closed. Days: 14 | Return: 0.95
# Std limit: 0.03676545530344327
# Pair ABT-BMY closed. Days: 22 | Return: 0.95
# Std limit: 0.033298714109866644
# Pair 162007Q-TOY closed. Days: 2 | Return: 0.95
# Std limit: 0.01540811649731839
# Pair 1005945D-ED closed. Days: 2 | Return: 1.0174218267771797
# Pair 1005945D-ED closed. Days: 20 | Return: 0.95
# Std limit: 0.02829479393813303
# Pair LDG-VVI closed. Days: 9 | Return: 1.0291298184766104
# Pair LDG-VVI closed. Days: 5 | Return: 0.95
# Pair LDG-VVI closed. Days: 11 | Return: 1.0416567733492506
# Pair LDG-VVI closed. Days: 6 | Return: 0.95
# Std limit: 0.042601355254094156
# Pair SPXC-VVI closed. Days: 3 | Return: 1.071359482590223
# Pair SPXC-VVI closed. Days: 17 | Return: 0.95
# Calculating returns from day 629 to 753
#
# ================ Period 6 ================
# Formation Period: 253 days | Trading Period: 127 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:24<00:00, 45.24it/s]
# Number of listed stocks in period: 477
# Period 6
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 476/476 [00:01<00:00, 417.71it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:33<00:00, 14.84it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1195
#  2. Pair:     SLB-1013207D | Hurst: 0.2370
#  3. Pair:     GPC-2218Q   | Hurst: 0.2444
#  4. Pair:     PAS-ADP     | Hurst: 0.2525
#  5. Pair: 571300Q-VZ      | Hurst: 0.2589
#  6. Pair: 1013207D-1291Q   | Hurst: 0.2594
#  7. Pair:   ENRNQ-93916Q  | Hurst: 0.2644
#  8. Pair:     PEG-0961514D | Hurst: 0.2672
#  9. Pair:     ADM-297504Q | Hurst: 0.2686
# 10. Pair: 1312089D-2691Q   | Hurst: 0.2702
# ------------------------------------------------------------------
#
# counter value: 753 | counter_temp = 753
# Portfolio period from days 1011 to 1137
# Std limit: 1.5815037859655932e-05
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000151254117782
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000297026758829
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000022373276103
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000282676560812
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000263407472838
# Pair JCI-1436513D closed. Days: 9 | Return: 1.000014762036684
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000220990036226
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000433405912115
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000050363185273
# Pair JCI-1436513D closed. Days: 8 | Return: 1.000014680268547
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000373223208057
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000349474452117
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000548515931662
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000240272635892
# Pair JCI-1436513D closed. Days: 6 | Return: 1.000057339491199
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000398309445857
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000167232843153
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000216426944113
# Std limit: 0.031032956423153665
# Std limit: 0.025920492600474333
# Pair GPC-2218Q closed. Days: 16 | Return: 0.95
# Pair GPC-2218Q did not converged, Days: 13 | Return: 0.9875413886598609
# Std limit: 0.03167474754614825
# Pair PAS-ADP closed. Days: 15 | Return: 0.95
# Pair PAS-ADP closed. Days: 4 | Return: 1.0275985000738976
# Pair PAS-ADP closed. Days: 2 | Return: 1.031745046431941
# Pair PAS-ADP closed. Days: 4 | Return: 1.0387955735817784
# Pair PAS-ADP closed. Days: 7 | Return: 1.072335988758198
# Std limit: 0.02977587448363803
# Pair 571300Q-VZ closed. Days: 9 | Return: 0.95
# Std limit: 0.043787203214903536
# Std limit: 0.030818005281801508
# Pair ENRNQ-93916Q closed. Days: 33 | Return: 1.063494140271448
# Pair ENRNQ-93916Q closed. Days: 11 | Return: 0.95
# Pair ENRNQ-93916Q closed. Days: 2 | Return: 1.0412960218883067
# Pair ENRNQ-93916Q did not converged, Days: 16 | Return: 0.996855003345124
# Std limit: 0.022118598656971317
# Pair PEG-0961514D closed. Days: 9 | Return: 1.0761733008465215
# Pair PEG-0961514D closed. Days: 3 | Return: 1.0393109634912465
# Pair PEG-0961514D did not converged, Days: 79 | Return: 1.0050450266884352
# Std limit: 0.04064285175555409
# Pair ADM-297504Q closed. Days: 2 | Return: 1.0414489478264624
# Pair ADM-297504Q closed. Days: 4 | Return: 1.0467809143720155
# Pair ADM-297504Q closed. Days: 5 | Return: 0.95
# Std limit: 0.04669132737357423
# Pair 1312089D-2691Q closed. Days: 10 | Return: 0.95
# Pair 1312089D-2691Q closed. Days: 48 | Return: 1.0585455774616654
# Pair 1312089D-2691Q did not converged, Days: 8 | Return: 0.9848292068340441
# Calculating returns from day 753 to 879
#
# ================ Period 7 ================
# Formation Period: 252 days | Trading Period: 126 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:22<00:00, 48.37it/s]
# Number of listed stocks in period: 475
# Period 7
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 474/474 [00:01<00:00, 440.38it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:30<00:00, 16.26it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1348
#  2. Pair:     HON-SHW     | Hurst: 0.2311
#  3. Pair:     MMM-PAS     | Hurst: 0.2444
#  4. Pair: 0948669D-USW     | Hurst: 0.2445
#  5. Pair:     ROH-2428Q   | Hurst: 0.2525
#  6. Pair:   2755Q-RYC     | Hurst: 0.2587
#  7. Pair:     SLB-1013207D | Hurst: 0.2623
#  8. Pair:     SLB-VZ      | Hurst: 0.2662
#  9. Pair:     CVX-677004Q | Hurst: 0.2687
# 10. Pair: 605555Q-ECL     | Hurst: 0.2718
# ------------------------------------------------------------------
#
# counter value: 879 | counter_temp = 879
# Portfolio period from days 1138 to 1263
# Std limit: 1.3724505651913735e-05
# Pair JCI-1436513D closed. Days: 3 | Return: 1.000036136049507
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000214894525548
# Pair JCI-1436513D closed. Days: 11 | Return: 1.0000340381729307
# Pair JCI-1436513D closed. Days: 6 | Return: 1.000033959378224
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000197670739701
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000328834374357
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000481678173578
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000021364931679
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000533420780862
# Pair JCI-1436513D closed. Days: 8 | Return: 1.0000350074435462
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000391794894965
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000023835716905
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000434912362135
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000457489721553
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000229602004302
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000408476610883
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000134275240307
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000232265332711
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000207478089773
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000207907953802
# Std limit: 0.036108404316050405
# Pair HON-SHW closed. Days: 14 | Return: 1.0395289355116437
# Pair HON-SHW closed. Days: 17 | Return: 1.030268097426697
# Pair HON-SHW closed. Days: 4 | Return: 1.0555679257400457
# Pair HON-SHW closed. Days: 7 | Return: 0.95
# Std limit: 0.02596874259887922
# Pair MMM-PAS closed. Days: 17 | Return: 0.95
# Pair MMM-PAS closed. Days: 22 | Return: 1.031523354034239
# Pair MMM-PAS closed. Days: 6 | Return: 1.0452612782161539
# Pair MMM-PAS closed. Days: 7 | Return: 0.95
# Std limit: 0.031128112068970582
# Pair 0948669D-USW closed. Days: 7 | Return: 1.0668120892926842
# Pair 0948669D-USW closed. Days: 3 | Return: 1.0529516798323995
# Pair 0948669D-USW closed. Days: 3 | Return: 0.95
# Pair 0948669D-USW did not converged, Days: 7 | Return: 1.0039751291774295
# Std limit: 0.026573945529576776
# Pair ROH-2428Q closed. Days: 7 | Return: 1.0418408145596587
# Pair ROH-2428Q closed. Days: 8 | Return: 0.95
# Pair ROH-2428Q closed. Days: 10 | Return: 0.95
# Std limit: 0.03145727162641285
# Pair 2755Q-RYC closed. Days: 71 | Return: 0.95
# Std limit: 0.026967671484718934
# Std limit: 0.03243082796156051
# Pair SLB-VZ closed. Days: 7 | Return: 1.0347300878302281
# Pair SLB-VZ closed. Days: 17 | Return: 1.077395586064068
# Pair SLB-VZ closed. Days: 2 | Return: 1.0359897999507897
# Pair SLB-VZ closed. Days: 17 | Return: 1.0751304972944
# Pair SLB-VZ closed. Days: 26 | Return: 1.0945312300016221
# Std limit: 0.020074218541335873
# Std limit: 0.03885298153455424
# Pair 605555Q-ECL closed. Days: 15 | Return: 1.0665053936572193
# Pair 605555Q-ECL closed. Days: 6 | Return: 1.057902350848653
# Pair 605555Q-ECL closed. Days: 8 | Return: 1.0457982552079148
# Pair 605555Q-ECL closed. Days: 3 | Return: 1.04191608345274
# Pair 605555Q-ECL closed. Days: 4 | Return: 1.0388961711722455
# Pair 605555Q-ECL closed. Days: 4 | Return: 1.0411745089017637
# Pair 605555Q-ECL did not converged, Days: 11 | Return: 0.9710258529379362
# Calculating returns from day 879 to 1004
#
# ================ Period 8 ================
# Formation Period: 253 days | Trading Period: 126 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:23<00:00, 46.60it/s]
# Number of listed stocks in period: 466
# Period 8
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 465/465 [00:02<00:00, 200.04it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:33<00:00, 14.80it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1032
#  2. Pair:      CL-PEP     | Hurst: 0.2541
#  3. Pair: 605555Q-MAT     | Hurst: 0.2548
#  4. Pair:     RTN-STI     | Hurst: 0.2583
#  5. Pair:     CVX-SHW     | Hurst: 0.2583
#  6. Pair: 210967Q-41018Q  | Hurst: 0.2598
#  7. Pair:    RDPL-329556Q | Hurst: 0.2615
#  8. Pair:     MKG-TRB     | Hurst: 0.2625
#  9. Pair:     PBI-1013207D | Hurst: 0.2632
# 10. Pair:     PBI-CVGYQ   | Hurst: 0.2649
# ------------------------------------------------------------------
#
# counter value: 1004 | counter_temp = 1004
# Portfolio period from days 1264 to 1389
# Std limit: 1.540371361406617e-05
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000315443298635
# Pair JCI-1436513D closed. Days: 7 | Return: 1.0000425046790786
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000203850402285
# Pair JCI-1436513D closed. Days: 8 | Return: 1.0000294721731624
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000266009767573
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000201719315018
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000197908416013
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000263514196006
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000193929625942
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000153006396804
# Pair JCI-1436513D closed. Days: 4 | Return: 1.000022655194849
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000019962472799
# Pair JCI-1436513D closed. Days: 4 | Return: 1.000018214090901
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000268117247404
# Pair JCI-1436513D closed. Days: 5 | Return: 1.0000226283483205
# Pair JCI-1436513D closed. Days: 10 | Return: 1.0000199355053474
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000022863257908
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000236655516086
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000265611065136
# Std limit: 0.038621291087815444
# Pair CL-PEP closed. Days: 3 | Return: 1.0339113720293718
# Pair CL-PEP closed. Days: 2 | Return: 0.95
# Std limit: 0.03880174739993725
# Std limit: 0.021316098996160045
# Pair RTN-STI closed. Days: 14 | Return: 0.95
# Pair RTN-STI closed. Days: 2 | Return: 1.020031419128755
# Pair RTN-STI closed. Days: 26 | Return: 1.0289893307756497
# Pair RTN-STI closed. Days: 2 | Return: 1.0458412077334414
# Pair RTN-STI closed. Days: 3 | Return: 1.0221019425923754
# Std limit: 0.033135741880563986
# Pair CVX-SHW closed. Days: 8 | Return: 1.0314822810737692
# Pair CVX-SHW closed. Days: 24 | Return: 1.0573823215558558
# Pair CVX-SHW closed. Days: 29 | Return: 1.0479540042361484
# Pair CVX-SHW did not converged, Days: 3 | Return: 1.0180864858343859
# Std limit: 0.02682683913606846
# Pair 210967Q-41018Q closed. Days: 8 | Return: 1.040170791756852
# Pair 210967Q-41018Q closed. Days: 7 | Return: 1.0475853894152878
# Pair 210967Q-41018Q closed. Days: 4 | Return: 1.0208038962835193
# Pair 210967Q-41018Q closed. Days: 31 | Return: 0.95
# Pair 210967Q-41018Q closed. Days: 3 | Return: 1.0191343343387695
# Pair 210967Q-41018Q did not converged, Days: 1 | Return: 1.0191343343387695
# Std limit: 0.02840320250603263
# Pair RDPL-329556Q closed. Days: 11 | Return: 1.028284462857224
# Pair RDPL-329556Q closed. Days: 3 | Return: 1.024372772645804
# Pair RDPL-329556Q closed. Days: 3 | Return: 1.0183460153889452
# Pair RDPL-329556Q closed. Days: 6 | Return: 1.0298224939849332
# Pair RDPL-329556Q closed. Days: 4 | Return: 1.0339155862001121
# Pair RDPL-329556Q closed. Days: 5 | Return: 0.95
# Std limit: 0.034125247602890145
# Pair MKG-TRB closed. Days: 6 | Return: 1.033709759819694
# Pair MKG-TRB closed. Days: 25 | Return: 1.04195690268071
# Pair MKG-TRB closed. Days: 10 | Return: 1.0440491551612483
# Pair MKG-TRB closed. Days: 9 | Return: 0.95
# Std limit: 0.032103155684547205
# Std limit: 0.02874340507315877
# Pair PBI-CVGYQ closed. Days: 3 | Return: 1.0301495561111196
# Pair PBI-CVGYQ closed. Days: 3 | Return: 1.0394207825901025
# Pair PBI-CVGYQ closed. Days: 6 | Return: 0.95
# Calculating returns from day 1004 to 1129
#
# ================ Period 9 ================
# Formation Period: 252 days | Trading Period: 126 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:21<00:00, 51.30it/s]
# Number of listed stocks in period: 463
# Period 9
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 462/462 [00:01<00:00, 454.62it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:33<00:00, 14.90it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1204
#  2. Pair:    BF_B-134618Q | Hurst: 0.2484
#  3. Pair:     HNZ-3891289Q | Hurst: 0.2599
#  4. Pair:     EIX-0111145D | Hurst: 0.2606
#  5. Pair:      JH-GIDL    | Hurst: 0.2639
#  6. Pair:     HSH-KRI     | Hurst: 0.2726
#  7. Pair:      VZ-3054Q   | Hurst: 0.2753
#  8. Pair:      VZ-DTE     | Hurst: 0.2798
#  9. Pair:     STI-OWENQ   | Hurst: 0.2802
# 10. Pair:     PBI-0848680D | Hurst: 0.2804
# ------------------------------------------------------------------
#
# counter value: 1129 | counter_temp = 1129
# Portfolio period from days 1390 to 1515
# Std limit: 1.6461728393258426e-05
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000176757325259
# Pair JCI-1436513D closed. Days: 46 | Return: 1.0000275372136516
# Pair JCI-1436513D closed. Days: 20 | Return: 1.0000200682849134
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000275731532782
# Pair JCI-1436513D closed. Days: 8 | Return: 1.0000220459949478
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000393415064102
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000272361309013
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000119713515827
# Pair JCI-1436513D did not converged, Days: 32 | Return: 0.9999886747096167
# Std limit: 0.03571493450399061
# Pair BF_B-134618Q closed. Days: 10 | Return: 0.95
# Pair BF_B-134618Q closed. Days: 6 | Return: 0.95
# Std limit: 0.034047444110520936
# Pair HNZ-3891289Q closed. Days: 29 | Return: 0.95
# Pair HNZ-3891289Q closed. Days: 5 | Return: 1.021726536474858
# Pair HNZ-3891289Q closed. Days: 6 | Return: 1.0198728864214748
# Pair HNZ-3891289Q closed. Days: 3 | Return: 1.030277856247678
# Pair HNZ-3891289Q closed. Days: 4 | Return: 1.0308362153914403
# Pair HNZ-3891289Q did not converged, Days: 15 | Return: 0.9695544310319045
# Std limit: 0.035061732786197106
# Pair EIX-0111145D closed. Days: 22 | Return: 1.0614518880485575
# Pair EIX-0111145D closed. Days: 2 | Return: 1.0675004332693028
# Pair EIX-0111145D closed. Days: 5 | Return: 1.0308509397908998
# Pair EIX-0111145D closed. Days: 3 | Return: 1.0312454683438852
# Pair EIX-0111145D closed. Days: 6 | Return: 0.95
# Std limit: 0.0401713736195434
# Pair JH-GIDL closed. Days: 17 | Return: 0.95
# Pair JH-GIDL closed. Days: 10 | Return: 1.0532728948571555
# Pair JH-GIDL closed. Days: 7 | Return: 1.0466547743792673
# Pair JH-GIDL closed. Days: 4 | Return: 0.95
# Std limit: 0.03224953201652852
# Pair HSH-KRI closed. Days: 6 | Return: 1.0425805928017047
# Pair HSH-KRI closed. Days: 6 | Return: 1.045096393138827
# Pair HSH-KRI closed. Days: 2 | Return: 1.029751988702649
# Pair HSH-KRI closed. Days: 5 | Return: 1.0503736750455195
# Pair HSH-KRI closed. Days: 25 | Return: 0.95
# Std limit: 0.03804950706490157
# Pair VZ-3054Q closed. Days: 6 | Return: 1.053880379633241
# Pair VZ-3054Q closed. Days: 48 | Return: 0.95
# Std limit: 0.02919616218391414
# Pair VZ-DTE closed. Days: 7 | Return: 1.0179827464176576
# Pair VZ-DTE closed. Days: 10 | Return: 1.0335946680807886
# Pair VZ-DTE closed. Days: 17 | Return: 1.0199297252269044
# Pair VZ-DTE closed. Days: 12 | Return: 1.0383643198448869
# Pair VZ-DTE closed. Days: 21 | Return: 0.95
# Std limit: 0.04280053703181938
# Pair STI-OWENQ closed. Days: 9 | Return: 1.0574770043227757
# Pair STI-OWENQ closed. Days: 6 | Return: 0.95
# Std limit: 0.04166597802635134
# Pair PBI-0848680D closed. Days: 13 | Return: 0.95
# Pair PBI-0848680D closed. Days: 16 | Return: 0.95
# Calculating returns from day 1129 to 1254
#
# ================ Period 10 ================
# Formation Period: 252 days | Trading Period: 128 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:21<00:00, 50.43it/s]
# Number of listed stocks in period: 467
# Period 10
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 466/466 [00:01<00:00, 420.47it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:34<00:00, 14.59it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.0994
#  2. Pair:     ECL-PAS     | Hurst: 0.2636
#  3. Pair:     VFC-DALRQ   | Hurst: 0.2639
#  4. Pair:     SHW-KRI     | Hurst: 0.2640
#  5. Pair:       D-CIN     | Hurst: 0.2664
#  6. Pair:     NSC-2638Q   | Hurst: 0.2672
#  7. Pair:   1958Q-GPUI    | Hurst: 0.2699
#  8. Pair:     WLA-IPG     | Hurst: 0.2740
#  9. Pair:     JCI-MEE     | Hurst: 0.2747
# 10. Pair:     MEE-1436513D | Hurst: 0.2747
# ------------------------------------------------------------------
#
# counter value: 1254 | counter_temp = 1254
# Portfolio period from days 1516 to 1643
# Std limit: 1.3024032402101933e-05
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000287947055195
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000135726761499
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000127766846163
# Pair JCI-1436513D closed. Days: 2 | Return: 1.000009368208049
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000119136821344
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000211279443476
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000113370659616
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000219158896781
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000229696940648
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000229698161314
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000240345070042
# Pair JCI-1436513D closed. Days: 6 | Return: 1.0000318358245017
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000145150348396
# Std limit: 0.034215085484668104
# Pair ECL-PAS closed. Days: 4 | Return: 1.0267252762757169
# Pair ECL-PAS closed. Days: 16 | Return: 1.0467286629959105
# Pair ECL-PAS closed. Days: 2 | Return: 1.0230231754256005
# Pair ECL-PAS closed. Days: 5 | Return: 1.0598736774181619
# Pair ECL-PAS closed. Days: 3 | Return: 0.95
# Std limit: 0.03714347335330888
# Pair VFC-DALRQ closed. Days: 3 | Return: 1.0549975134889253
# Pair VFC-DALRQ closed. Days: 5 | Return: 0.95
# Std limit: 0.031498911743899634
# Pair SHW-KRI closed. Days: 18 | Return: 0.95
# Pair SHW-KRI closed. Days: 7 | Return: 0.95
# Std limit: 0.03053855453283521
# Pair D-CIN closed. Days: 72 | Return: 0.95
# Std limit: 0.03631721406692149
# Pair NSC-2638Q closed. Days: 18 | Return: 1.0467628792058397
# Pair NSC-2638Q closed. Days: 11 | Return: 1.0454658497473412
# Pair NSC-2638Q closed. Days: 16 | Return: 0.95
# Std limit: 0.039233294243407615
# Std limit: 0.03780948087354478
# Pair WLA-IPG closed. Days: 7 | Return: 1.0506467840514313
# Pair WLA-IPG closed. Days: 21 | Return: 0.95
# Std limit: 0.03957067777258619
# Pair JCI-MEE closed. Days: 6 | Return: 0.95
# Pair JCI-MEE closed. Days: 9 | Return: 0.95
# Pair JCI-MEE closed. Days: 9 | Return: 0.95
# Std limit: 0.03957158308409576
# Pair MEE-1436513D closed. Days: 6 | Return: 0.95
# Pair MEE-1436513D closed. Days: 9 | Return: 0.95
# Pair MEE-1436513D closed. Days: 9 | Return: 0.95
# Calculating returns from day 1254 to 1381
#
# ================ Period 11 ================
# Formation Period: 254 days | Trading Period: 125 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:25<00:00, 42.63it/s]
# Number of listed stocks in period: 467
# Period 11
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 466/466 [00:01<00:00, 442.06it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:30<00:00, 16.51it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1075
#  2. Pair:      GE-PFE     | Hurst: 0.2350
#  3. Pair: 987200Q-R       | Hurst: 0.2364
#  4. Pair:     PBI-3621240Q | Hurst: 0.2432
#  5. Pair:     ALL-HIG     | Hurst: 0.2441
#  6. Pair:    FNMA-PNC     | Hurst: 0.2484
#  7. Pair:    FNMA-MRK     | Hurst: 0.2508
#  8. Pair:     SAF-TMK     | Hurst: 0.2541
#  9. Pair:     ITW-3346Q   | Hurst: 0.2556
# 10. Pair:      SO-PPL     | Hurst: 0.2588
# ------------------------------------------------------------------
#
# counter value: 1381 | counter_temp = 1381
# Portfolio period from days 1644 to 1768
# Std limit: 1.0409820205112135e-05
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000096387755708
# Pair JCI-1436513D closed. Days: 5 | Return: 1.0000277708000456
# Pair JCI-1436513D closed. Days: 2 | Return: 1.00002045619413
# Pair JCI-1436513D closed. Days: 4 | Return: 1.0000199987670013
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000101556224568
# Pair JCI-1436513D closed. Days: 4 | Return: 1.000019951235699
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000206910971612
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000106759401417
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000206658753856
# Pair JCI-1436513D closed. Days: 2 | Return: 1.0000088688800548
# Pair JCI-1436513D closed. Days: 3 | Return: 1.0000198605589057
# ...
# Pair BDX-SYK closed. Days: 14 | Return: 1.0179594988623177
# Pair BDX-SYK closed. Days: 65 | Return: 0.95
# Std limit: 0.026041264548279996
# Std limit: 0.025161674585730796
# Pair LMT-NTRS closed. Days: 19 | Return: 0.95
# Std limit: 0.028195490103718367
# Pair BLL-NTRS closed. Days: 9 | Return: 1.0474822341435406
# Pair BLL-NTRS closed. Days: 22 | Return: 0.95
# Std limit: 0.026849974176187515
# Pair SIAL-INTU closed. Days: 14 | Return: 1.0261002442060088
# Pair SIAL-INTU closed. Days: 5 | Return: 1.0266020085000842
# Pair SIAL-INTU closed. Days: 19 | Return: 0.95
# Std limit: 0.035756717134075536
# Pair LMT-INTU closed. Days: 26 | Return: 0.95
# Pair LMT-INTU closed. Days: 19 | Return: 0.95
# Std limit: 0.03536047038747402
# Pair LNC-IVZ closed. Days: 4 | Return: 1.0230364340091718
# Pair LNC-IVZ closed. Days: 14 | Return: 0.95
# Pair LNC-IVZ closed. Days: 9 | Return: 1.0355818635823613
# Pair LNC-IVZ closed. Days: 22 | Return: 0.95
# Calculating returns from day 5375 to 5498
#
# ================ Period 44 ================
# Formation Period: 249 days | Trading Period: 128 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:24<00:00, 44.59it/s]
# Number of listed stocks in period: 477
# Period 44
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 476/476 [00:01<00:00, 313.22it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:38<00:00, 12.84it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1256
#  2. Pair:    BF_B-SYY     | Hurst: 0.2359
#  3. Pair:    BF_B-CL      | Hurst: 0.2374
#  4. Pair:     APD-FMC     | Hurst: 0.2644
#  5. Pair:    BF_B-MKC     | Hurst: 0.2763
#  6. Pair:     TAP-MDLZ    | Hurst: 0.2764
#  7. Pair:    BF_B-CTAS    | Hurst: 0.2782
#  8. Pair:    BF_B-FISV    | Hurst: 0.2816
#  9. Pair:     GWW-DIS     | Hurst: 0.2835
# 10. Pair:      KO-TE      | Hurst: 0.2883
# ------------------------------------------------------------------
#
# counter value: 5498 | counter_temp = 5498
# Portfolio period from days 5794 to 5921
# Std limit: 1.6313153186317627e-06
# Std limit: 0.02208911888302098
# Std limit: 0.029035271217323258
# Std limit: 0.026655472215080363
# Pair APD-FMC closed. Days: 12 | Return: 0.95
# Pair APD-FMC closed. Days: 40 | Return: 1.0314362730575286
# Pair APD-FMC did not converged, Days: 8 | Return: 1.0212288354693964
# Std limit: 0.022602785736198495
# Std limit: 0.03354647046244651
# Pair TAP-MDLZ closed. Days: 11 | Return: 1.0658448563461775
# Pair TAP-MDLZ closed. Days: 2 | Return: 1.0341334162123694
# Pair TAP-MDLZ closed. Days: 5 | Return: 1.0296003607123232
# Std limit: 0.035498011362324236
# Std limit: 0.029900445495574943
# Std limit: 0.030709582571766952
# Pair GWW-DIS closed. Days: 2 | Return: 1.0234541140448625
# Pair GWW-DIS closed. Days: 15 | Return: 1.0270570490724005
# Pair GWW-DIS closed. Days: 14 | Return: 1.0304260247850652
# Pair GWW-DIS closed. Days: 4 | Return: 1.040427892115058
# Pair GWW-DIS closed. Days: 18 | Return: 0.95
# Std limit: 0.027538674774965785
# Pair KO-TE closed. Days: 27 | Return: 1.0669867703351301
# Pair KO-TE closed. Days: 27 | Return: 1.0240545020734069
# Pair KO-TE closed. Days: 4 | Return: 1.021652611316978
# Pair KO-TE did not converged, Days: 36 | Return: 0.9705480713066241
# Calculating returns from day 5498 to 5625
#
# ================ Period 45 ================
# Formation Period: 252 days | Trading Period: 124 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:22<00:00, 47.91it/s]
# Number of listed stocks in period: 478
# Period 45
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 477/477 [00:01<00:00, 426.56it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:31<00:00, 16.04it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1244
#  2. Pair:    BF_B-AEE     | Hurst: 0.2352
#  3. Pair:    BF_B-WMT     | Hurst: 0.2376
#  4. Pair:     BDX-OMC     | Hurst: 0.2542
#  5. Pair:      NI-DISCA   | Hurst: 0.2572
#  6. Pair:      HD-C       | Hurst: 0.2652
#  7. Pair:   CMCSA-CTAS    | Hurst: 0.2658
#  8. Pair:    BF_B-TROW    | Hurst: 0.2664
#  9. Pair:     TAP-MDLZ    | Hurst: 0.2668
# 10. Pair:    BF_B-CB      | Hurst: 0.2678
# ------------------------------------------------------------------
#
# counter value: 5625 | counter_temp = 5625
# Portfolio period from days 5922 to 6045
# Std limit: 1.488225460963421e-06
# Std limit: 0.0220413457978832
# Std limit: 0.021924127856515926
# Std limit: 0.027557707521203893
# Pair BDX-OMC closed. Days: 4 | Return: 1.0470148851760543
# Pair BDX-OMC closed. Days: 20 | Return: 1.0224942481377421
# Pair BDX-OMC closed. Days: 12 | Return: 1.0237053668497362
# Pair BDX-OMC closed. Days: 4 | Return: 1.0219310939939366
# Pair BDX-OMC closed. Days: 25 | Return: 0.95
# Std limit: 0.028780351092392666
# Pair NI-DISCA closed. Days: 7 | Return: 0.95
# Std limit: 0.030504899986425874
# Pair HD-C closed. Days: 23 | Return: 0.95
# Std limit: 0.03333983309378341
# Pair CMCSA-CTAS closed. Days: 3 | Return: 1.0345357199640368
# Pair CMCSA-CTAS closed. Days: 13 | Return: 1.0371440825137839
# Pair CMCSA-CTAS closed. Days: 43 | Return: 1.069253456290006
# Pair CMCSA-CTAS did not converged, Days: 37 | Return: 0.9869955195587321
# Std limit: 0.02955059777904764
# Std limit: 0.03030309211637943
# Pair TAP-MDLZ closed. Days: 60 | Return: 0.95
# Std limit: 0.031136006819669198
# Calculating returns from day 5625 to 5748
#
# ================ Period 46 ================
# Formation Period: 252 days | Trading Period: 128 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:23<00:00, 47.34it/s]
# Number of listed stocks in period: 481
# Period 46
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 480/480 [00:01<00:00, 313.10it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:34<00:00, 14.48it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1343
#  2. Pair:     MMM-MDLZ    | Hurst: 0.2390
#  3. Pair:     LEG-KRFT    | Hurst: 0.2426
#  4. Pair:      SO-HCBK    | Hurst: 0.2605
#  5. Pair:      PG-WMT     | Hurst: 0.2648
#  6. Pair:     LEG-MAC     | Hurst: 0.2681
#  7. Pair:     MKC-HCBK    | Hurst: 0.2736
#  8. Pair:     ARG-DG      | Hurst: 0.2763
#  9. Pair:     HRS-LMT     | Hurst: 0.2775
# 10. Pair:     AFL-NWSA    | Hurst: 0.2809
# ------------------------------------------------------------------
#
# counter value: 5748 | counter_temp = 5748
# Portfolio period from days 6046 to 6173
# Std limit: 1.281716699678073e-06
# Std limit: 0.027660370448791414
# Pair MMM-MDLZ closed. Days: 28 | Return: 0.95
# Std limit: 0.02236164738213564
# Pair LEG-KRFT closed. Days: 5 | Return: 0.95
# Std limit: 0.022120995555644
# Pair SO-HCBK closed. Days: 12 | Return: 1.0360286524217037
# Pair SO-HCBK closed. Days: 5 | Return: 0.95
# Std limit: 0.012751605081671315
# Pair PG-WMT closed. Days: 64 | Return: 0.95
# Pair PG-WMT did not converged, Days: 21 | Return: 0.9989348403792596
# Std limit: 0.022825949426716712
# Pair LEG-MAC closed. Days: 3 | Return: 1.0224347484234095
# Pair LEG-MAC closed. Days: 8 | Return: 1.032055855212334
# Pair LEG-MAC closed. Days: 33 | Return: 0.95
# Pair LEG-MAC closed. Days: 6 | Return: 0.95
# Pair LEG-MAC closed. Days: 7 | Return: 1.038235367648197
# Std limit: 0.027737600453221628
# Pair MKC-HCBK closed. Days: 5 | Return: 1.0237087356157135
# Pair MKC-HCBK closed. Days: 7 | Return: 0.95
# Std limit: 0.030207420309180437
# Pair ARG-DG closed. Days: 18 | Return: 1.035752724449587
# Pair ARG-DG closed. Days: 4 | Return: 1.1250117076432258
# Pair ARG-DG closed. Days: 24 | Return: 1.0495344668008468
# Pair ARG-DG closed. Days: 9 | Return: 1.0251835184667863
# Pair ARG-DG closed. Days: 33 | Return: 0.95
# Std limit: 0.029708385811827043
# Std limit: 0.0329324954858311
# Pair AFL-NWSA closed. Days: 64 | Return: 1.0494208034259271
# Pair AFL-NWSA closed. Days: 5 | Return: 1.0359864296410248
# Pair AFL-NWSA did not converged, Days: 44 | Return: 0.9813639475114784
# Calculating returns from day 5748 to 5875
#
# ================ Period 47 ================
# Formation Period: 252 days | Trading Period: 124 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:23<00:00, 47.16it/s]
# Number of listed stocks in period: 479
# Period 47
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 478/478 [00:01<00:00, 271.04it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:31<00:00, 16.02it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1344
#  2. Pair:     CVS-ALL     | Hurst: 0.2745
#  3. Pair:     GPC-PNW     | Hurst: 0.2746
#  4. Pair:     MMC-MDT     | Hurst: 0.2779
#  5. Pair:     ROK-MOS     | Hurst: 0.2816
#  6. Pair:     MMC-ZBH     | Hurst: 0.2854
#  7. Pair:    VIAB-NWSA    | Hurst: 0.2869
#  8. Pair:     VFC-CB      | Hurst: 0.2915
#  9. Pair:     NSC-MCO     | Hurst: 0.2919
# 10. Pair:     GIS-ORCL    | Hurst: 0.2919
# ------------------------------------------------------------------
#
# counter value: 5875 | counter_temp = 5875
# Portfolio period from days 6174 to 6297
# Std limit: 8.479900520820011e-07
# Std limit: 0.01969490377031696
# Pair CVS-ALL closed. Days: 26 | Return: 0.95
# Std limit: 0.01978384624168383
# Std limit: 0.0267587480872699
# Std limit: 0.024969008833233303
# Pair ROK-MOS closed. Days: 11 | Return: 0.95
# Pair ROK-MOS closed. Days: 27 | Return: 0.95
# Std limit: 0.031029586765998672
# Pair MMC-ZBH closed. Days: 70 | Return: 1.0312272417909414
# Pair MMC-ZBH closed. Days: 8 | Return: 1.0575634350868115
# Pair MMC-ZBH closed. Days: 9 | Return: 1.021021643048011
# Std limit: 0.027102146336549334
# Pair VIAB-NWSA closed. Days: 14 | Return: 0.95
# Pair VIAB-NWSA did not converged, Days: 5 | Return: 0.9841501366637309
# Std limit: 0.02764310378648308
# Pair VFC-CB closed. Days: 14 | Return: 1.0297595453171586
# Pair VFC-CB closed. Days: 6 | Return: 1.0519343896543156
# Pair VFC-CB did not converged, Days: 95 | Return: 0.9724929852296709
# Std limit: 0.03325200510947019
# Pair NSC-MCO closed. Days: 19 | Return: 1.048832464730638
# Pair NSC-MCO closed. Days: 9 | Return: 1.0418778332760288
# Pair NSC-MCO closed. Days: 8 | Return: 0.95
# Std limit: 0.026534477934976777
# Pair GIS-ORCL closed. Days: 9 | Return: 1.0558242537694613
# Pair GIS-ORCL closed. Days: 7 | Return: 1.0346641917300106
# Pair GIS-ORCL closed. Days: 23 | Return: 1.0334899677137317
# Pair GIS-ORCL closed. Days: 9 | Return: 1.0389682396405384
# Pair GIS-ORCL closed. Days: 9 | Return: 1.025624256334476
# Pair GIS-ORCL did not converged, Days: 8 | Return: 0.9763754934804508
# Calculating returns from day 5875 to 5998
#
# ================ Period 48 ================
# Formation Period: 252 days | Trading Period: 127 days
# Generating Assets Price Index
# 100%|███████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:26<00:00, 41.85it/s]
# Number of listed stocks in period: 468
# Period 48
# --- Starting Stage 1: Pre-selecting candidates with Distance Method (SSE) ---
# Stage 1: Calculating SSE: 100%|██████████████████████████████████████████████████████| 467/467 [00:01<00:00, 251.52it/s]
# --- Stage 1 Complete: 500 candidate pairs selected. ---
# --- Starting Stage 2: Calculating Hurst Exponent for candidate pairs... ---
# Stage 2: Calculating Hurst: 100%|█████████████████████████████████████████████████████| 500/500 [00:36<00:00, 13.70it/s]
# --- Stage 2 Complete. Finalizing pair selection... ---
#
# --- Top Selected Pairs for this Period (Ranked by Hurst Exponent) ---
#  1. Pair:     JCI-1436513D | Hurst: 0.1168
#  2. Pair:     ABT-HBAN    | Hurst: 0.2568
#  3. Pair:     UTX-LLTC    | Hurst: 0.2592
#  4. Pair:     CSC-ADBE    | Hurst: 0.2669
#  5. Pair:     SYY-WY      | Hurst: 0.2692
#  6. Pair:     TRV-ZBH     | Hurst: 0.2719
#  7. Pair:     APD-FIS     | Hurst: 0.2812
#  8. Pair:      MS-STT     | Hurst: 0.2826
#  9. Pair:     BEN-XYL     | Hurst: 0.2827
# 10. Pair:     STI-EXPD    | Hurst: 0.2840
# ------------------------------------------------------------------
#
# counter value: 5998 | counter_temp = 5998
# Portfolio period from days 6298 to 6424
# Std limit: 8.651555753681862e-07
# Std limit: 0.021610982378600797
# Std limit: 0.025136052109203333
# Pair UTX-LLTC closed. Days: 9 | Return: 1.0717841414213887
# Pair UTX-LLTC closed. Days: 4 | Return: 1.0316408697889299
# Pair UTX-LLTC closed. Days: 30 | Return: 0.95
# Std limit: 0.027654311284401902
# Pair CSC-ADBE closed. Days: 25 | Return: 0.95
# Std limit: 0.022863929570437373
# Pair SYY-WY closed. Days: 21 | Return: 0.95
# Std limit: 0.022333674472506355
# Std limit: 0.023871834543198914
# Pair APD-FIS closed. Days: 13 | Return: 0.95
# Std limit: 0.027641395837772274
# Pair MS-STT closed. Days: 28 | Return: 1.041373154836158
# Std limit: 0.032027054459813055
# Pair BEN-XYL closed. Days: 41 | Return: 0.95
# Std limit: 0.030478994430252343
# Calculating returns from day 5998 to 6124
#
#
# ========================================================
#            FINAL PORTFOLIO ANALYSIS
# ========================================================
#
# --- Descriptive Statistics for the Most Traded Assets (Table 2) ---
#   Symbol   Mean Std Dev     SR    Min   Max
#      JCI 0.0007  0.0196 0.5695 -12.49 13.70
# 1436513D 0.0007  0.0196 0.5695 -12.49 13.70
#     BF_B 0.0006  0.0144 0.6915  -9.89 16.07
#      MRO 0.0004  0.0216 0.2981 -19.56 23.36
#      SYY 0.0006  0.0157 0.5592  -9.30 13.67
#      PAS 0.0005  0.0197 0.4388 -22.75 25.96
#      APD 0.0006  0.0179 0.5261 -12.31 14.65
#      SHW 0.0007  0.0179 0.6549 -20.79 15.26
#      ALL 0.0006  0.0202 0.4341 -21.18 21.69
#     SPGI 0.0007  0.0178 0.5896 -13.78 23.84
#      PLL 0.0007  0.0198 0.5232 -22.58 19.44
#
#
# --- Performance Metrics of Trading Strategies (Table 3) ---
#                              Committed Capital Fully Invested
# Mean Return (%)                          1.517          6.998
# Sharpe Ratio                            -0.296          0.198
# Sortino Ratio                           -0.417          0.275
# t-statistic                              1.482          1.582
# % of negative excess returns             53.26          52.03
# MDD (%)                                 -10.21         -56.24
# Annualized STD (%)                       4.759         20.568
# Skewness                                 0.607          0.959
# Kurtosis                                 9.056         18.139
# Minimum Daily Ret (%)                   -1.798        -11.531
# Maximum Daily Ret (%)                    2.957         14.784
#
# --- Generating Cumulative Excess Returns Plot ---
# Displaying plot...
# ========================================================
#                  ANALYSIS COMPLETE
# ========================================================

# %%
# --------------------
# Generating chart
# --------------------
import matplotlib.pyplot as plt

print("\n--- Generating Cumulative Excess Returns Plot ---")

# We will plot only the "Committed Capital" strategy returns.
# First, get the series of non-zero daily returns for this strategy.
cc_returns = Rp_ew_cc[Rp_ew_cc['Return'] != 0]['Return'].dropna()

# Get the corresponding risk-free rates for the same days
if not cc_returns.empty:
    rf_returns = risk_free.loc[cc_returns.index, 'Return'].dropna()

    # Calculate the excess returns
    cc_excess_returns = cc_returns - rf_returns

    # Calculate the cumulative product of the excess returns
    cumulative_cc = (1 + cc_excess_returns).cumprod()

    # Use a simple numerical series (0, 1, 2, ...) for the x-axis
    x_axis_data = range(len(cumulative_cc))

    # --- Create the plot ---
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, ax = plt.subplots(figsize=(14, 8))

    ax.plot(x_axis_data, cumulative_cc, label='Committed Capital', linewidth=2, color='C0') # 'C0' is default blue

    # Add titles and labels for clarity
    ax.set_title('Cumulative Excess Returns (Committed Capital)', fontsize=16)
    ax.set_xlabel('Trading Days', fontsize=12)
    ax.set_ylabel('Cumulative Excess Returns', fontsize=12)
    ax.legend(fontsize=12)

    # Set a baseline at 1.0 for reference
    ax.axhline(y=1, color='grey', linestyle='--', linewidth=1)
    
    print("Displaying plot...")
    plt.show()

    fig = ax.get_figure()
    fig.savefig('./hurst_cumm_return.png')
    
else:
    print("No trading data available to generate the plot.")

print("\n========================================================")
print("                 ANALYSIS COMPLETE")
print("========================================================")
# Out:
# --- Generating Cumulative Excess Returns Plot ---
# Displaying plot...
# ========================================================
#                  ANALYSIS COMPLETE
# ========================================================
