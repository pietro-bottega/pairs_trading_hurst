# %%
import os
import datetime
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.tsa.stattools as ts

# %%
read_csv = False
s1218 = 1
years = 2015 - 1990 + 0.5
stop_loss = float('-inf')
duration_limit = 50

# %%
# MQO para encontrar o coeficiente de cointegração e criando a serie do spread
def OLS(data_ticker1, data_ticker2):
    spread = sm.OLS(data_ticker1,data_ticker2)
    spread = spread.fit()
    return data_ticker1 + (data_ticker2 * -spread.params.iloc[0]), spread.params.iloc[0]


# ADF test
def ADF(spread):
    return ts.adfuller(spread) # H0: Raiz unitária.


# Encontra o coeficiente de cointegração e realiza o ADF test
def ADF_test(data_ticker1, data_ticker2):
    ols = OLS(data_ticker1, data_ticker2)
    spread = ols[0]
    gamma = ols[1]
    return ADF(spread),gamma


# Encontra os pares cointegrados
def find_cointegrated_pairs_mod(data):
    try:
        print(f"Finding cointegrated pairs for shape {np.shape(data)}")
        n = data.shape[1]
        pvalue_matrix = np.ones((n, n))
        gammas_matrix= np.ones((n, n))
        keys = data.keys()
        for i in range(n):
            for j in range(i+1, n):
                S1 = keys[i]
                S2 = keys[j]
                #print(f"Testing cointegration for pairs {S1} and {S2}")
                result = ADF_test(data[S1], data[S2])
                gammas_matrix[i, j] =result[1] # gamma
                pvalue = result[0][1] # pvalue
                pvalue_matrix[i, j] = pvalue
            if(i%50 == 0):
                print(f"Finished pairs for stock {keys[i]}")
        return pvalue_matrix, gammas_matrix
    except Exception as e:
        print(e)


# Ordenando os melhores pares
def top_coint_pairs(data,pvalue_matrix,gamma, alpha, n): 
#alpha = nivel de significancia para o teste ADF
#n = top n ativos com o menor pvalue    
    alpha_filter = np.where(pvalues < alpha)
    pvalues_f = pvalues[alpha_filter] # pvalores menores que alpha
    #print(f"Alpha filter rows len {len(alpha_filter[0])} | cols len {len(alpha_filter[1])} | value {alpha_filter}")
    #print(f"pvalues_f len: {np.shape(pvalues_f)} | value: {pvalues_f}")
    stock_a = data.columns[list(alpha_filter)[0]] # relacionando o pvalor com a ação A
    stock_b = data.columns[list(alpha_filter)[1]] # relacionando o pvalor com a ação B
    gammas_f = gammas[alpha_filter] # relacionando o pvalor com o gamma
    N = len(list(alpha_filter[0])) # quantidade de pares cointegrados

    d = []
    for i in range(N):
        pair_dict = {
            'Stock A': stock_a[i],
            'Stock B': stock_b[i],
            'P-Values': pvalues_f[i],
            'Gamma': gammas_f[i]
        }
        #if(i%2000 == 0):
        #print(f"Appending pair dict: {pair_dict}")
        d.append(pair_dict)

    return pd.DataFrame(d).sort_values(by="P-Values").iloc[:n,]


# Calcula os retornos da carteira e armazenando em um data frame
def calculate_profit(pair, spread, threshold, par1, par2, resumo, semester, gamma):
    #print(f"Calculating profits for pair {par1}-{par2}")
    
    #print(f"Spread series: {spread}")
    
    date_format = "%Y-%m-%d"
    
    log_ret = spread.diff() # log return eh o incremento
    #print(f"log_ret len: {len(log_ret)} | variable: {log_ret}")
    dias = spread.index
    #print(f"Dias len: {len(dias)} | variable: {dias}")
    z_score = (spread-spread.mean())/spread.std()
    z_score.plot()
    #print(f"Z-score index: {z_score.index} | variable: {z_score}")
    portfolio_return = []
    pos = 0 # 0: sem posição aberta
            # 1: Comprei o meu portfolio h = (1,-gamma)
            # -1: Vendi o meu portfolio h = -(1,-gamma)

    dias_abertura = []
    dias_fechamento = []

    count = 0
    dia_abertura = 0
    dia_fechamento = 0
    
    closing_threshold = 0.5
    
    for i in z_score.index:   
        if (z_score[i] > threshold) and (pos == 0):
            # Posição fechada no par e com sinal short 1st e long 2nd
            pos = -1

            count += 1
            dia_abertura = dias[i - dias[0]]
            retornos_op = []


        elif (z_score[i] < -threshold)  and (pos == 0):
            # Posição fechada no par e com sinal de long 1st e short 2nd 
            pos = 1            

            count += 1
            dia_abertura = dias[i - dias[0]]
            retornos_op = []

        else:
            #print(f"Dia {i} | Pos {pos} | log_ret {log_ret[i]} | S1 return {returns[par1][i]} | S2 return {returns[par2][i]} | Net {pos*(returns[par1][i] - gamma*returns[par2][i])}")

            if (pos == 1) and (z_score[i] >= -closing_threshold or sum(retornos_op) < stop_loss):
                # Posição vendida aberta no par e com sinal de convergência
                portfolio_return.append(log_ret[i]*pos)
                pos = 0

                dia_fechamento = dias[i - dias[0]]
                delta_dias = dia_fechamento - dia_abertura
                if sum(retornos_op) < stop_loss:
                    print(f"Sum: {sum(retornos_op)}")
                    retorno_op = stop_loss
                    print(f"Retorno_op: {retorno_op}")
                else:
                    retornos_op.append(log_ret[i]*pos)
                    retorno_op = pd.Series(retornos_op).sum()

                Rpair[i-1, pair] = log_ret[i]*pos
                
                resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, True])

            elif (pos == -1) and (z_score[i] <= closing_threshold or sum(retornos_op) < stop_loss):
                portfolio_return.append(log_ret[i]*pos)
                pos = 0

                dia_fechamento = dias[i - dias[0]]
                delta_dias = dia_fechamento - dia_abertura
                if sum(retornos_op) < stop_loss:
                    print(f"Sum: {sum(retornos_op)}")
                    retorno_op = stop_loss
                    print(f"Retorno_op: {retorno_op}")
                else:
                    retornos_op.append(log_ret[i]*pos)
                    retorno_op = pd.Series(retornos_op).sum()

                Rpair[i-1, pair] = log_ret[i]*pos
                
                resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, True])
                
            elif (pos == 1) and (z_score[i] < -closing_threshold):
                # Posição vendidada aberta no par aberta e sem convergência
                portfolio_return.append(log_ret[i]*pos)
                retornos_op.append(log_ret[i]*pos)
                
                Rpair[i-1, pair] = log_ret[i]*pos
            
            elif (pos == -1) and (z_score[i] > closing_threshold):
                portfolio_return.append(log_ret[i]*pos)
                retornos_op.append(log_ret[i]*pos)

                Rpair[i-1, pair] = log_ret[i]*pos

            else:
                # Sem posição aberta e nem sinal de entrada
                
                if pos != 0:
                    dia_fechamento = dias[i - dias[0]]
                    delta_dias = dia_fechamento - dia_abertura
                    retornos_op.append(log_ret[i]*pos)
                    retorno_op = pd.Series(retornos_op).sum()

                    Rpair[i-1, pair] = log_ret[i]*pos
                    
                    resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, True])

                pos = 0

    if pos != 0:
        # Operação sem convergência
        pos = 0

        dia_fechamento = i
        delta_dias = dia_fechamento - dia_abertura
        retorno_op = pd.Series(retornos_op).sum()
        print(f"Par {par1}-{par2} sem convergência, retorno_op: {retorno_op}")
        resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, False])
                
    #print(f"Total return: {sum(pair_returns)} | Pair returns: {pair_returns}")
    #print(f"Conversão do par: {pos}")    
    total_ret = pd.Series(portfolio_return).sum()

    return total_ret, resumo


# Calcula o expoente de hurst
def get_hurst_exponent(time_series):
    
    # Definindo o intervalo de taus
    max_tau = round(len(time_series)/4)
    taus = range(2, max_tau)

    # Calculando a variável k
    k = [np.std(np.subtract(time_series[tau:], time_series[:-tau])) for tau in taus]
    
    'To calculate the Hurst exponent, we first calculate the standard deviation of the differences between a series and its lagged version, for a range of possible lags.'

    # Calculate the slope of the log plot -> the Hurst Exponent
    reg = np.polyfit(np.log(taus), np.log(k), 1)
    
    'We then estimate the Hurst exponent as the slope of the log-log plot of the number of lags versus the mentioned standard deviations.'

    return reg[0]

# %%
prices = pd.read_csv("../cointegration_data/Pt_cointegration.csv")
returns = pd.read_csv("../cointegration_data/Rt_cointegration.csv")
periods = pd.read_csv("../distance_data/Periods.csv", header=None)
ticker2 = pd.read_csv("../distance_data/ticker2.csv", header=None)
ticker_b = pd.read_csv("../distance_data/ticker_b.csv", header=None)

print(prices)
print(returns)
# Out:
#            UN  1005945D  162007Q     RDPL      BGG    SKY    GOSHA      HSY  \
# 0      3.3082   11.7377  32.6951  10.2566   3.6022  7.723  13.6570   5.3707
# 1      3.3321   11.8106  32.1859  10.2396   3.5747  7.657  13.7545   5.3175
# 2      3.2699   11.5919  30.7599  10.1207   3.4922  7.591  13.4619   5.2112
# 3      3.3082   11.6648  32.0840  10.1886   3.4647  7.657  13.6570   5.3175
# 4      3.2986   11.6648  31.6766  10.2226   3.4510  7.591  13.6570   5.3884
# ...       ...       ...      ...      ...      ...    ...      ...      ...
# 6421  43.5600       NaN      NaN      NaN  16.9300    NaN      NaN  90.3200
# 6422  43.7100       NaN      NaN      NaN  16.7100    NaN      NaN  90.3900
# 6423  44.2300       NaN      NaN      NaN  17.8500    NaN      NaN  90.9800
# 6424  44.0400       NaN      NaN      NaN  17.6200    NaN      NaN  90.6000
# 6425  43.3200       NaN      NaN      NaN  17.3000    NaN      NaN  89.2700
#
#           NMK      WLB  ...    MNST        O     JBHT   BXLT   ENDP    EQIX  \
# 0     10.9995  23.0656  ...     NaN      NaN   2.8041    NaN    NaN     NaN
# 1     10.9022  23.0656  ...     NaN      NaN   2.7715    NaN    NaN     NaN
# 2     10.7075  23.0656  ...     NaN      NaN   2.7715    NaN    NaN     NaN
# 3     10.8048  23.0656  ...     NaN      NaN   2.7715    NaN    NaN     NaN
# 4     10.8048  22.8278  ...     NaN      NaN   2.6737    NaN    NaN     NaN
# ...       ...      ...  ...     ...      ...      ...    ...    ...     ...
# 6421      NaN   6.3800  ...  148.82  50.9280  72.9700  39.27  62.62  297.19
# 6422      NaN   5.9900  ...  148.16  51.3748  72.8800  38.49  61.82  300.91
# 6423      NaN   5.8900  ...  150.17  51.8016  73.5100  39.39  62.49  304.98
# 6424      NaN   5.7700  ...  150.24  51.7329  73.0300  39.10  62.42  302.69
# 6425      NaN   5.8800  ...  148.96  51.4439  73.1600  39.03  61.22  302.40
#
#       1436513D  1431816D       SPGI  1448062D
# 0       1.4481    2.7908   3.875790       NaN
# 1       1.4655    2.7288   3.858865       NaN
# 2       1.4655    2.6668   3.841940       NaN
# 3       1.4713    2.7288   3.841940       NaN
# 4       1.4365    2.6357   3.841940       NaN
# ...        ...       ...        ...       ...
# 6421   39.6647       NaN  96.685191       NaN
# 6422   39.0673       NaN  96.201661       NaN
# 6423   39.6843       NaN  96.181929       NaN
# 6424   39.4003       NaN  98.678493       NaN
# 6425   38.6756       NaN  98.540344       NaN
#
# [6426 rows x 1100 columns]
#             UN  1005945D   162007Q      RDPL       BGG       SKY     GOSHA  \
# 0     0.007224  0.006211 -0.015574 -0.001657 -0.007634 -0.008546  0.007139
# 1    -0.018667 -0.018517 -0.044305 -0.011612 -0.023079 -0.008620 -0.021273
# 2     0.011713  0.006289  0.043046  0.006709 -0.007875  0.008695  0.014493
# 3    -0.002902  0.000000 -0.012698  0.003337 -0.003954 -0.008620  0.000000
# 4    -0.005821  0.000000 -0.016078 -0.003326  0.007969  0.000000 -0.028571
# ...        ...       ...       ...       ...       ...       ...       ...
# 6420 -0.001604       NaN       NaN       NaN -0.005288       NaN       NaN
# 6421  0.003444       NaN       NaN       NaN -0.012995       NaN       NaN
# 6422  0.011897       NaN       NaN       NaN  0.068223       NaN       NaN
# 6423 -0.004296       NaN       NaN       NaN -0.012885       NaN       NaN
# 6424 -0.016349       NaN       NaN       NaN -0.018161       NaN       NaN
#
#            HSY       NMK       WLB  ...      MNST         O      JBHT  \
# 0    -0.009906 -0.008846  0.000000  ...       NaN       NaN -0.011626
# 1    -0.019991 -0.017859  0.000000  ...       NaN       NaN  0.000000
# 2     0.020398  0.009087  0.000000  ...       NaN       NaN  0.000000
# 3     0.013333  0.000000 -0.010310  ...       NaN       NaN -0.035288
# 4     0.009873 -0.009005  0.000000  ...       NaN       NaN  0.024386
# ...        ...       ...       ...  ...       ...       ...       ...
# 6420 -0.000221       NaN -0.013910  ...  0.009154 -0.004077  0.004128
# 6421  0.000775       NaN -0.061129  ... -0.004435  0.008773 -0.001233
# 6422  0.006527       NaN -0.016694  ...  0.013566  0.008308  0.008644
# 6423 -0.004177       NaN -0.020374  ...  0.000466 -0.001326 -0.006530
# 6424 -0.014680       NaN  0.019064  ... -0.008520 -0.005586  0.001780
#
#           BXLT      ENDP      EQIX  1436513D  1431816D      SPGI  1448062D
# 0          NaN       NaN       NaN  0.012016 -0.022216 -0.004367       NaN
# 1          NaN       NaN       NaN  0.000000 -0.022721 -0.004386       NaN
# 2          NaN       NaN       NaN  0.003958  0.023249  0.000000       NaN
# 3          NaN       NaN       NaN -0.023653 -0.034118  0.000000       NaN
# 4          NaN       NaN       NaN -0.016150  0.011800 -0.008811       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 6420 -0.001526 -0.001435 -0.000538 -0.004915       NaN  0.021689       NaN
# 6421 -0.019862 -0.012775  0.012517 -0.015061       NaN -0.005001       NaN
# 6422  0.023383  0.010838  0.013526  0.015793       NaN -0.000205       NaN
# 6423 -0.007362 -0.001120 -0.007509 -0.007156       NaN  0.025957       NaN
# 6424 -0.001790 -0.019225 -0.000958 -0.018393       NaN -0.001400       NaN
#
# [6425 rows x 1100 columns]

# %%
# Conversão dos dados para log dos preços
log_data = np.log(prices)
print(log_data.head())
# Out:
#          UN  1005945D   162007Q      RDPL       BGG       SKY     GOSHA  \
# 0  1.196404  2.462806  3.487225  2.327921  1.281545  2.044203  2.614252
# 1  1.203603  2.468997  3.471528  2.326263  1.273881  2.035620  2.621366
# 2  1.184759  2.450307  3.426212  2.314583  1.250532  2.026963  2.599863
# 3  1.196404  2.456576  3.468357  2.321269  1.242626  2.035620  2.614252
# 4  1.193498  2.456576  3.455578  2.324601  1.238664  2.026963  2.614252
#
#         HSY       NMK       WLB  ...  MNST   O      JBHT  BXLT  ENDP  EQIX  \
# 0  1.680958  2.397850  3.138342  ...   NaN NaN  1.031083   NaN   NaN   NaN
# 1  1.671003  2.388965  3.138342  ...   NaN NaN  1.019389   NaN   NaN   NaN
# 2  1.650810  2.370944  3.138342  ...   NaN NaN  1.019389   NaN   NaN   NaN
# 3  1.671003  2.379990  3.138342  ...   NaN NaN  1.019389   NaN   NaN   NaN
# 4  1.684248  2.379990  3.127979  ...   NaN NaN  0.983463   NaN   NaN   NaN
#
#    1436513D  1431816D      SPGI  1448062D
# 0  0.370252  1.026328  1.354750       NaN
# 1  0.382196  1.003862  1.350373       NaN
# 2  0.382196  0.980879  1.345977       NaN
# 3  0.386146  1.003862  1.345977       NaN
# 4  0.362210  0.969149  1.345977       NaN
#
# [5 rows x 1100 columns]
# /home/pietro-bottega/miniconda3/envs/pairs_trading_crisis/lib/python3.13/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
no_pairs = 20
days, num_assets = np.shape(returns)
first_traininig = int(periods.iloc[0, 3])
Rpair = np.zeros((days, no_pairs))

# %%
results = []
resumos = []
alpha = 0.05
threshold = 1

read_csv = False

past_days=0

for big_loop in range(0, int(years * 2 - 2)):
    print(f"Starting period {big_loop} | Past days: {past_days}")
    
    twelve_months = int(periods.iloc[big_loop, 3])
    six_months = int(periods.iloc[big_loop + 2, 0])
    
    # Limpeza das ações não listadas no período
    listed1 = log_data.iloc[past_days, :] > 0
    listed2 = log_data.iloc[past_days+int(twelve_months+six_months*(s1218 == 1))-1, :] > 0
    listed = np.multiply(listed1, listed2)
    listed_num = np.sum(listed)
    #print(f"Listed stocks for the period: {listed_num}")
    listed_indexes = np.where(listed > 0)[0]
    #print(f"Listed indexes len {np.shape(listed_indexes)} value {listed_indexes}")
    listed_stocks = log_data.columns[listed_indexes]
    
    #print(f"First listed stockes len {np.shape(listed_stocks)} value {listed_stocks}")
    
    [D, ia, ib] = np.intersect1d(
        ticker2.iloc[:, big_loop], ticker2.iloc[:, big_loop+1], return_indices=True)
    
    ic = np.isin(D, ticker2.iloc[:, big_loop+2])
    
    #print(f"ic len: {np.shape(ic)} | variable: {ic}")
    #print(f"D(ic) len: {np.shape(D[ic])} | variable: {D[ic]}")
    
    Dic_unique_sorted, B_idx = np.unique(D[ic], return_index=True)
    #print(f"Dic_unique_sorted len: {np.shape(Dic_unique_sorted)} | variable: {Dic_unique_sorted}")
    
    listed_union = np.intersect1d(listed_stocks,Dic_unique_sorted)
    #print(f"Listed union len {np.shape(listed_union)} value {listed_union}")
    
    index_listed2 = [log_data.columns.get_loc(i) for i in listed_union if i in log_data]
    index_listed2.sort()
    #print(f"Listed union indexes len {np.shape(index_listed2)} value {index_listed2}")
    
    if os.path.exists(f"../cointegration_data/pvalues_semester_{big_loop}.csv"):
        print("Reading csv")
        try:
            pvalues = np.genfromtxt(f"../cointegration_data/pvalues_semester_{big_loop}.csv", delimiter=',')
            #pvalues = pd.read_csv(f"cointegration_data/pvalues_semester_{j}.csv", header=None, index_col=False)
            gammas = np.genfromtxt(f"../cointegration_data/gammas_semester_{big_loop}.csv", delimiter=',')
            #gammas = pd.read_csv(f"cointegration_data/gammas_semester_{j}.csv", header=None, index_col=False)
        except Exception as e:
            print(e)
    else:
        print("Generating csv")
        result = find_cointegrated_pairs_mod(log_data.iloc[past_days:(past_days+twelve_months),index_listed2]) # 1 ano de formação e 6 meses de teste
        if result is None:
                print("Retornou None")
        else:
            pvalues, gammas = result
    '''   
    pd.DataFrame(pvalues).to_csv(f"../cointegration_data/pvalues_semester_{big_loop}.csv", header=None, index=False)
    pd.DataFrame(gammas).to_csv(f"../cointegration_data/gammas_semester_{big_loop}.csv", header=None, index=False)
    '''
    print(f"Finished finding cointegrated pairs big_loop {big_loop}")

    try:
        coint_pairs_df = top_coint_pairs(log_data.iloc[past_days:(past_days+twelve_months),index_listed2], pvalues, gammas, alpha, no_pairs)
        print(f"Found top cointegrated pairs big_loop {big_loop}")
        #print(f"coint_pairs_df len: {np.shape(coint_pairs_df)} | value: {coint_pairs_df}")
    except Exception as e:
        print(e)
        print("Exception ao achar top pares cointegrados")
        continue
        
    for i in range(0,coint_pairs_df.shape[0]):
        #print(f"Pair: {coint_pairs_df.iloc[i,:]}")
        
        S1_name = coint_pairs_df.iloc[i, 0]
        S2_name = coint_pairs_df.iloc[i, 1]
        gamma_1_2 = coint_pairs_df.iloc[i, 3]

        S1 = log_data[S1_name].iloc[(past_days+twelve_months):(past_days+twelve_months+six_months)] # periodo de teste
        S2 = log_data[S2_name].iloc[(past_days+twelve_months):(past_days+twelve_months+six_months)] # periodo de teste

        # Spread
        spread = S1 - gamma_1_2*S2
        #print(f"Spread series: {spread}")
        # Pegando o resultado da estratégia
        ret, resumos = calculate_profit(i, spread, threshold, S1_name, S2_name, resumos, big_loop, gamma_1_2)
        
    past_days = past_days + periods.iloc[big_loop, 0]
    
    
cols = ['Operação', 'Semestre', 'Abertura', 'Fechamento', 'Dias', 'Retorno total', 'Ticker 1', 'Ticker 2', 'Converged']
df = pd.DataFrame(resumos, columns = cols)
df['Index'] = df['Ticker 1'].astype(str) + '-' + df['Ticker 2'].astype(str) + '-' + df['Operação'].astype(str)
df['Retorno total - exp'] = np.exp(df['Retorno total'])
df.to_csv("../cointegration_results/operations.csv", sep=',', index=False)
# Out:
# Starting period 0 | Past days: 0
# Reading csv
# Finished finding cointegrated pairs big_loop 0
# Found top cointegrated pairs big_loop 0
# Par 291784Q-ZRN sem convergência, retorno_op: -0.021293801916080435
# Par 291784Q-CKL sem convergência, retorno_op: -0.0014008908502836093
# Par PRDCQ-291784Q sem convergência, retorno_op: 0.0221216247515148
# Par TKR-291784Q sem convergência, retorno_op: 8.433689302989045e-05
# Par BAC1-291784Q sem convergência, retorno_op: 0.024100151350528787
# Par MZIAQ-291784Q sem convergência, retorno_op: -0.0576911038673904
# Par HON-291784Q sem convergência, retorno_op: -0.106233097280505
# Par MSI-291784Q sem convergência, retorno_op: -0.0024847559055496404
# Par 8214761Q-291784Q sem convergência, retorno_op: 0.045401593045460764
# Par 1166Q-291784Q sem convergência, retorno_op: 0.004058494467329421
# Par FDX-291784Q sem convergência, retorno_op: 0.019199812313325015
# Par RML-291784Q sem convergência, retorno_op: -0.21126503795347684
# Par 291784Q-ACKH sem convergência, retorno_op: 0.022137638731165366
# Par 291784Q-504369Q sem convergência, retorno_op: -0.03528506419441424
# Par 291784Q-3459Q sem convergência, retorno_op: -0.004390458599224489
# Par 1530Q-291784Q sem convergência, retorno_op: 0.029458879010228145
# Par 291784Q-ASH sem convergência, retorno_op: -0.013519606531977812
# Par 297504Q-291784Q sem convergência, retorno_op: -0.0127563102503645
# Starting period 1 | Past days: 127
# Reading csv
# Finished finding cointegrated pairs big_loop 1
# Found top cointegrated pairs big_loop 1
# Par CKL-NAV sem convergência, retorno_op: 0.0067677822797707066
# Par UCL-183291Q sem convergência, retorno_op: -0.0015305179473696917
# Par DALRQ-1423Q sem convergência, retorno_op: -0.06536558101386891
# Par 0948669D-TCOMA sem convergência, retorno_op: 0.026268336040200513
# Par K-183291Q sem convergência, retorno_op: -0.1051524220982114
# Par USG-0943554D sem convergência, retorno_op: -0.06316963125004937
# Par 183291Q-DTE sem convergência, retorno_op: 0.03765184134608468
# Par WNDXQ-1671Q sem convergência, retorno_op: -0.029046722883444343
# Par FFB-183291Q sem convergência, retorno_op: -0.01329018179020558
# Par 3621240Q-183291Q sem convergência, retorno_op: 0.05095179272874173
# Par CGP-2770014Q sem convergência, retorno_op: 0.03907880714905554
# Par DUK-XRX sem convergência, retorno_op: -0.01567250288309463
# Par NEM-363096Q sem convergência, retorno_op: 0.011589008044906368
# Par 950967Q-2254Q sem convergência, retorno_op: -0.012034028210442083
# Par USW-2746Q sem convergência, retorno_op: -0.11383160646075785
# Starting period 2 | Past days: 252
# Reading csv
# Finished finding cointegrated pairs big_loop 2
# Found top cointegrated pairs big_loop 2
# Par 0598884D-1051665D sem convergência, retorno_op: -0.02898739879784351
# Par DALRQ-363096Q sem convergência, retorno_op: -0.06414766445808473
# Par WY-2987Q sem convergência, retorno_op: 0.048472835841858464
# Par 0948669D-HP sem convergência, retorno_op: 0.012767893493419447
# Par K-363096Q sem convergência, retorno_op: -0.032106499404132904
# Par 363096Q-1802Q sem convergência, retorno_op: -0.037334338592000194
# Par 1255177D-UPJ sem convergência, retorno_op: -0.04569826371171981
# Par FFB-363096Q sem convergência, retorno_op: 0.06426478938918212
# Par TOY-300583Q sem convergência, retorno_op: -0.008850702552366752
# Par 1051665D-2784Q sem convergência, retorno_op: -0.03900949264280085
# Par HTMXQ-363096Q sem convergência, retorno_op: 0.02950077647729077
# Par VVI-3891289Q sem convergência, retorno_op: -0.022128939681020254
# Par DOW-WMB sem convergência, retorno_op: 0.0171536155570442
# Par 3517233Q-93916Q sem convergência, retorno_op: -0.09307083966320784
# Par USW-1513Q sem convergência, retorno_op: -0.043321618990320054
# Par 667517Q-NEC sem convergência, retorno_op: 0.042356210716150144
# Starting period 3 | Past days: 380
# Reading csv
# Finished finding cointegrated pairs big_loop 3
# Found top cointegrated pairs big_loop 3
# Par 1581Q-UIS sem convergência, retorno_op: -0.012461990759139674
# Par 0598884D-3459Q sem convergência, retorno_op: -0.08546721833960769
# Par WMT-MSI sem convergência, retorno_op: -0.11015715965896478
# Par 0598884D-1377Q sem convergência, retorno_op: -0.06716135647062593
# Par APD-NEU sem convergência, retorno_op: -0.10172005470609058
# Par CLX-PET sem convergência, retorno_op: 0
# Par 0598884D-2650Q sem convergência, retorno_op: -0.07633685837641258
# Par LK-SHW sem convergência, retorno_op: 0.03606441976853292
# Par 3022239Q-134618Q sem convergência, retorno_op: 0.009252812912193376
# Par BCR-SGP sem convergência, retorno_op: 0.03168771432379991
# Par FL-3517233Q sem convergência, retorno_op: -0.02437957425063564
# Par 3022239Q-RYC sem convergência, retorno_op: -0.06108874863439362
# Par FNMA-3022239Q sem convergência, retorno_op: -0.013249920049473118
# Starting period 4 | Past days: 506
# Reading csv
# Finished finding cointegrated pairs big_loop 4
# Found top cointegrated pairs big_loop 4
# Par KBH-ADP sem convergência, retorno_op: -0.012477212590847442
# Par PNC-1013207D sem convergência, retorno_op: -0.006566057080554133
# Par FFB-1013207D sem convergência, retorno_op: -0.008285860373941745
# Par C-0202445Q sem convergência, retorno_op: -0.17324316270403584
# Par KMB-MDR sem convergência, retorno_op: 0.025333930334205945
# Par 0202445Q-375573Q sem convergência, retorno_op: -0.03589938217555311
# Par 0202445Q-MAT sem convergência, retorno_op: -0.10796583026069606
# Par APD-NEU sem convergência, retorno_op: -0.016641182192602244
# Par CLX-JH sem convergência, retorno_op: -0.058141022406809295
# Par 0202445Q-SKLNQ sem convergência, retorno_op: -0.07082312936752766
# Par MCD-1013207D sem convergência, retorno_op: 0.007512036401314592
# Par LK-SHW sem convergência, retorno_op: 0.02947578920311056
# Par 3022239Q-1567Q sem convergência, retorno_op: 0
# Par 3022239Q-3459Q sem convergência, retorno_op: -0.01248922973868094
# Par FNMA-3022239Q sem convergência, retorno_op: -0.06717681125768449
# Starting period 5 | Past days: 634
# Reading csv
# Finished finding cointegrated pairs big_loop 5
# index 486 is out of bounds for axis 0 with size 486
# Exception ao achar top pares cointegrados
# Starting period 6 | Past days: 634
# Reading csv
# Finished finding cointegrated pairs big_loop 6
# index 480 is out of bounds for axis 0 with size 480
# Exception ao achar top pares cointegrados
# Starting period 7 | Past days: 634
# Reading csv
# Finished finding cointegrated pairs big_loop 7
# index 476 is out of bounds for axis 0 with size 476
# Exception ao achar top pares cointegrados
# Starting period 8 | Past days: 634
# Reading csv
# Finished finding cointegrated pairs big_loop 8
# index 466 is out of bounds for axis 0 with size 466
# Exception ao achar top pares cointegrados
# Starting period 9 | Past days: 634
# Reading csv
# Finished finding cointegrated pairs big_loop 9
# index 459 is out of bounds for axis 0 with size 459
# Exception ao achar top pares cointegrados
# Starting period 10 | Past days: 634
# Reading csv
# Finished finding cointegrated pairs big_loop 10
# index 459 is out of bounds for axis 0 with size 459
# Exception ao achar top pares cointegrados
# Starting period 11 | Past days: 634
# Reading csv
# Finished finding cointegrated pairs big_loop 11
# Found top cointegrated pairs big_loop 11
# Par GWW-1284849D sem convergência, retorno_op: 0.03622796153183394
# Par ADP-PBY sem convergência, retorno_op: 0
# Par CCK-TOY sem convergência, retorno_op: 0.016661806879039176
# Par 3517233Q-329556Q sem convergência, retorno_op: 0
# Par CSC-2288005Q sem convergência, retorno_op: -0.022787848688994083
# Par MEL-2428Q sem convergência, retorno_op: 0.013268991379408623
# Par 0544749D-929530Q sem convergência, retorno_op: -0.045497548140950084
# Par BGG-WWY sem convergência, retorno_op: -0.03248931420200174
# Par IP-PBI sem convergência, retorno_op: 0.004727417636400499
# Par 2251Q-3520842Q sem convergência, retorno_op: -0.05067927607892875
# Starting period 12 | Past days: 760
# Reading csv
# Finished finding cointegrated pairs big_loop 12
# Found top cointegrated pairs big_loop 12
# Par 0111145D-3692470Q sem convergência, retorno_op: -0.05022358129268012
# Par ENRNQ-93916Q sem convergência, retorno_op: -0.0030281240416871746
# Par EXC-950967Q sem convergência, retorno_op: 0.013340348303993332
# Par 605555Q-HNZ sem convergência, retorno_op: 0.03715933166228336
# Par 605555Q-VZ sem convergência, retorno_op: -0.0033942113659488626
# Par JH-929530Q sem convergência, retorno_op: -0.01720407188978612
# Par NUE-ARB sem convergência, retorno_op: -0.038531754697368914
# Par 2727195Q-1013207D sem convergência, retorno_op: -0.02185681678561524
# Par CAG-1028411Q sem convergência, retorno_op: 0.007982172929136944
# Par NSC-TXT sem convergência, retorno_op: 0
# Starting period 13 | Past days: 888
# Reading csv
# Finished finding cointegrated pairs big_loop 13
# index 445 is out of bounds for axis 0 with size 445
# Exception ao achar top pares cointegrados
# Starting period 14 | Past days: 888
# Reading csv
# Finished finding cointegrated pairs big_loop 14
# Found top cointegrated pairs big_loop 14
# Par CBE-RRD sem convergência, retorno_op: 0
# Par CCTYQ-ADBE sem convergência, retorno_op: 0.1748791624186472
# Par CCK-3619382Q sem convergência, retorno_op: -0.0858171599987747
# Par KRI-CTB sem convergência, retorno_op: -0.026163069446273113
# Par INTC-ITT sem convergência, retorno_op: -0.06263842419386223
# Par 3277Q-LDG sem convergência, retorno_op: 0.022487234220768038
# Par PPG-PRDCQ sem convergência, retorno_op: 0
# Par CBE-X sem convergência, retorno_op: 0
# Par ITW-TMC sem convergência, retorno_op: -0.015345829617890772
# Par HON-CNRG sem convergência, retorno_op: -0.13990075171938487
# Par ITW-RBD sem convergência, retorno_op: -0.11167363905524796
# Par LOW-CCTYQ sem convergência, retorno_op: 0.0660245206385528
# Par EMR-ITW sem convergência, retorno_op: -0.044201002979258774
# Par C-L sem convergência, retorno_op: -0.04421340182418598
# Par 1255177D-PX sem convergência, retorno_op: 0.016198960330016554
# Par RSHCQ-BSX sem convergência, retorno_op: -0.04251361725370417
# Starting period 15 | Past days: 1016
# Reading csv
# Finished finding cointegrated pairs big_loop 15
# index 427 is out of bounds for axis 0 with size 427
# Exception ao achar top pares cointegrados
# Starting period 16 | Past days: 1016
# Reading csv
# Finished finding cointegrated pairs big_loop 16
# index 424 is out of bounds for axis 0 with size 423
# Exception ao achar top pares cointegrados
# Starting period 17 | Past days: 1016
# Reading csv
# Finished finding cointegrated pairs big_loop 17
# index 419 is out of bounds for axis 0 with size 418
# Exception ao achar top pares cointegrados
# Starting period 18 | Past days: 1016
# Reading csv
# Finished finding cointegrated pairs big_loop 18
# Found top cointegrated pairs big_loop 18
# Par NRTLQ-WHR sem convergência, retorno_op: -0.03609054874531603
# Par LNC-HNZ sem convergência, retorno_op: 0.04181506501051757
# Par CR-AMGN sem convergência, retorno_op: 0.04040046833625199
# Par MCD-BDK sem convergência, retorno_op: -0.025260766989765315
# Par PDG-PX sem convergência, retorno_op: 0.021154210737277968
# Par EKDKQ-EMN sem convergência, retorno_op: 0.008144277666060962
# Par ABT-AMGN sem convergência, retorno_op: 0.06541444134448815
# Par TRB-EMN sem convergência, retorno_op: -0.05422205451573259
# Par WFC-MS sem convergência, retorno_op: -0.027114613440360147
# Par MCD-AMGN sem convergência, retorno_op: 0.03741426789370861
# Par XRX-AON sem convergência, retorno_op: -0.09890385426223514
# Par KR-EFX sem convergência, retorno_op: -0.043055567431939945
# Par NOC-605555Q sem convergência, retorno_op: -0.07047236058749906
# Starting period 19 | Past days: 1144
# Reading csv
# Finished finding cointegrated pairs big_loop 19
# Found top cointegrated pairs big_loop 19
# Par HPC-IPG sem convergência, retorno_op: -0.03929809186172761
# Par DCNAQ-DALRQ sem convergência, retorno_op: -0.031143339737838005
# Par WFC-WAMUQ sem convergência, retorno_op: -0.018385042437679244
# Par KO-PBI sem convergência, retorno_op: -0.07817516522033818
# Par BMS-HM sem convergência, retorno_op: -0.06607254270856178
# Par HSH-1028411Q sem convergência, retorno_op: -0.03409956031322281
# Par UNP-EFX sem convergência, retorno_op: 0.031960306473793665
# Par AEP-CMS sem convergência, retorno_op: 0.00801490771138047
# Par WY-2942331Q sem convergência, retorno_op: -0.014093760856646487
# Par COST-M sem convergência, retorno_op: 0.014799419085465004
# Par FBF-MCK sem convergência, retorno_op: 0.019749158065407446
# Par WYE-ADP sem convergência, retorno_op: -0.06126751937572994
# Starting period 20 | Past days: 1270
# Reading csv
# Finished finding cointegrated pairs big_loop 20
# Found top cointegrated pairs big_loop 20
# Par KMB-WNDXQ sem convergência, retorno_op: -0.04764054138973117
# Par XOM-LMT sem convergência, retorno_op: -0.02035480715142679
# Par MAT-SIAL sem convergência, retorno_op: -0.030786931085935887
# Par JCP-MDP sem convergência, retorno_op: -0.09093391420413344
# Par KR-CNCEQ sem convergência, retorno_op: -0.0014584275765894272
# Par ETN-MAT sem convergência, retorno_op: -0.08694256779668974
# Par THC-MDP sem convergência, retorno_op: -0.024990303394419655
# Par ETN-TXT sem convergência, retorno_op: -0.02923918583441898
# Par 3393199Q-1028411Q sem convergência, retorno_op: 0
# Par PKI-AMGN sem convergência, retorno_op: -0.04010458278701412
# Par C-DUK sem convergência, retorno_op: -0.0336450513315798
# Par ETN-MDP sem convergência, retorno_op: -0.00897276980335171
# Par 2942331Q-ADI sem convergência, retorno_op: 0.04300177987386444
# Par ROH-HCR sem convergência, retorno_op: 0.03808292848322381
# Starting period 21 | Past days: 1396
# Reading csv
# Finished finding cointegrated pairs big_loop 21
# Found top cointegrated pairs big_loop 21
# Par GDW-2727195Q sem convergência, retorno_op: -0.05003503998606673
# Par JPM-UNP sem convergência, retorno_op: -0.007364074863661418
# Par PBI-3621240Q sem convergência, retorno_op: 0.03860701467592609
# Par GE-PFE sem convergência, retorno_op: -0.022304487773338266
# Par CCL-355488Q sem convergência, retorno_op: 0.026256807712188746
# Par BMY-ALL sem convergência, retorno_op: -0.03896808336381152
# Par TXT-HAS sem convergência, retorno_op: -0.03260316266402796
# Par MDT-MOLX sem convergência, retorno_op: -0.04098894991214408
# Par 987200Q-R sem convergência, retorno_op: -0.013894928301880771
# Par JPM-ABKFQ sem convergência, retorno_op: -0.016724352174692925
# Par GDW-JPM sem convergência, retorno_op: -0.012232574467506918
# Par JPM-MBI sem convergência, retorno_op: -0.043442444122069546
# Par PTC-4621824Q sem convergência, retorno_op: -0.016007024245733525
# Starting period 22 | Past days: 1521
# Reading csv
# Finished finding cointegrated pairs big_loop 22
# Found top cointegrated pairs big_loop 22
# Par FNMA-EMR sem convergência, retorno_op: -0.04838576180052723
# Par WFC-UNH sem convergência, retorno_op: -0.08332603906720903
# Par FNMA-TNB sem convergência, retorno_op: -0.07123300204334626
# Par MDT-BBBY sem convergência, retorno_op: -0.02000086994334671
# Par 3621240Q-SIAL sem convergência, retorno_op: -0.0834575137834479
# Par UNH-BK sem convergência, retorno_op: -0.06539829123418639
# Par UNH-CCE sem convergência, retorno_op: -0.09880013662756637
# Par APD-9876566D sem convergência, retorno_op: -0.010095548995768588
# Par FNMA-SAF sem convergência, retorno_op: -0.06902208297126666
# Par UNH-CNCEQ sem convergência, retorno_op: 0.01696561175007605
# Par BC-NCC sem convergência, retorno_op: -0.07753628199700646
# Par ABT-MMC sem convergência, retorno_op: -0.0011738603254594082
# Par TLAB-BBBY sem convergência, retorno_op: -0.08078180894857878
# Starting period 23 | Past days: 1644
# Reading csv
# Finished finding cointegrated pairs big_loop 23
# Found top cointegrated pairs big_loop 23
# Par QTRN-GENZ sem convergência, retorno_op: -0.08945215074376822
# Par SGP-HMA sem convergência, retorno_op: -0.008309782624031481
# Par KEY-ZION sem convergência, retorno_op: -0.03214091546483511
# Par PFE-HMA sem convergência, retorno_op: -0.023592286317799083
# Par D-3517233Q sem convergência, retorno_op: -0.01591106158449751
# Par 2968900Q-VMC sem convergência, retorno_op: -0.08786797532321211
# Par WFC-HMA sem convergência, retorno_op: -0.08171396134744136
# Par AZO-EQR sem convergência, retorno_op: -0.01971084912832133
# Par 3286728Q-PX sem convergência, retorno_op: -0.012253203725810291
# Par AON-ABKFQ sem convergência, retorno_op: 0.02195999293674955
# Par ADI-SANM sem convergência, retorno_op: -0.11960837279626624
# Par NTRS-HMA sem convergência, retorno_op: -0.02978793830367854
# Par TOY-BC sem convergência, retorno_op: 0.001475083600179783
# Starting period 24 | Past days: 1768
# Reading csv
# Finished finding cointegrated pairs big_loop 24
# Found top cointegrated pairs big_loop 24
# Par BEAM-SVU sem convergência, retorno_op: -0.060814817900861406
# Par CLX-SPGI sem convergência, retorno_op: -0.008899808413186161
# Par MXIM-PCL sem convergência, retorno_op: -0.09721474267209329
# Par STT-XL sem convergência, retorno_op: -0.05602431537971375
# Par 0948669D-CTAS sem convergência, retorno_op: -0.14348091546422825
# Par ECL-MEL sem convergência, retorno_op: -0.06129612081005842
# Par MEL-ZION sem convergência, retorno_op: -0.030615586497776626
# Par CMA-NTRS sem convergência, retorno_op: -0.03132870472798821
# Par 0948669D-ABKFQ sem convergência, retorno_op: -0.06141858849776227
# Par ROK-MXIM sem convergência, retorno_op: -0.003558534754272369
# Par ZION-APOL sem convergência, retorno_op: 0.13770216367680765
# Par COST-CCL sem convergência, retorno_op: 0.01264248803965895
# Starting period 25 | Past days: 1896
# Reading csv
# Finished finding cointegrated pairs big_loop 25
# Found top cointegrated pairs big_loop 25
# Par 0964591D-SPGI sem convergência, retorno_op: 0
# Par GPS-PVN sem convergência, retorno_op: -0.08381319533542442
# Par DOW-EP sem convergência, retorno_op: -0.045008815094786936
# Par WHR-2676187Q sem convergência, retorno_op: -0.045862101865687066
# Par MCD-UIS sem convergência, retorno_op: 0.018698684480340955
# Par MMC-MAS sem convergência, retorno_op: 0
# Par 2968900Q-EA sem convergência, retorno_op: -0.06637298472184838
# Par 1028411Q-2676187Q sem convergência, retorno_op: -0.15720195903476242
# Par RTN-SNV sem convergência, retorno_op: -0.014770508385724579
# Par 2676187Q-LEG sem convergência, retorno_op: -0.07050060095018695
# Starting period 26 | Past days: 2020
# Reading csv
# Finished finding cointegrated pairs big_loop 26
# Found top cointegrated pairs big_loop 26
# Par KR-PTC sem convergência, retorno_op: -0.06594805240483304
# Par SHW-TROW sem convergência, retorno_op: -0.049187926013451566
# Par WMT-SPGI sem convergência, retorno_op: -0.07656027593597203
# Par WBA-PTC sem convergência, retorno_op: 0.02284055408374286
# Par PTC-BBT sem convergência, retorno_op: -0.28310271645173346
# Par GPS-SPLS sem convergência, retorno_op: -0.1529430802701488
# Par CLX-PTC sem convergência, retorno_op: 0.10051136487039392
# Par BCR-PTC sem convergência, retorno_op: -0.04650221052139303
# Par BK-PTC sem convergência, retorno_op: -0.02030713504808679
# Par MCD-ZION sem convergência, retorno_op: -0.009008114950826762
# Par PTC-SWY sem convergência, retorno_op: -0.05568861812356651
# Par ABT-FITB sem convergência, retorno_op: -0.05619618389745451
# Par ABT-PTC sem convergência, retorno_op: -0.005542506470232578
# Par PFE-PTC sem convergência, retorno_op: -0.008309582015904482
# Par 1028411Q-WAMUQ sem convergência, retorno_op: -0.0915194254381837
# Par RTN-EQR sem convergência, retorno_op: 0.04598395905981034
# Par PEP-PTC sem convergência, retorno_op: 0.0604923178854504
# Starting period 27 | Past days: 2148
# Reading csv
# Finished finding cointegrated pairs big_loop 27
# Found top cointegrated pairs big_loop 27
# Par BK-HOG sem convergência, retorno_op: -0.02853119838753493
# Par ROH-OMX sem convergência, retorno_op: -0.0340892001172044
# Par TER-CVG sem convergência, retorno_op: -0.1778032488780008
# Par GP-1317355D sem convergência, retorno_op: -0.0836756340096878
# Par JPM-CPB sem convergência, retorno_op: 0.051159889459425845
# Par 2942331Q-CCL sem convergência, retorno_op: 0.024142859144296924
# Par BOL-TXT sem convergência, retorno_op: -0.15289790035959117
# Par MOLX-CIEN sem convergência, retorno_op: -0.013268760097167487
# Par JPM-CCL sem convergência, retorno_op: 0.0560299721629578
# Par XRX-MAT sem convergência, retorno_op: -0.11436428519058861
# Starting period 28 | Past days: 2272
# Reading csv
# Finished finding cointegrated pairs big_loop 28
# Found top cointegrated pairs big_loop 28
# Par SBUX-PMCS sem convergência, retorno_op: -0.11102621730397622
# Par MERQ-SBUX sem convergência, retorno_op: 0.24131917558684268
# Par BA-WM sem convergência, retorno_op: -0.09618760765078882
# Par NEE-WM sem convergência, retorno_op: 0
# Par LNC-WM sem convergência, retorno_op: -0.18439274151936802
# Par MAR-WM sem convergência, retorno_op: -0.07838174350471494
# Par SBUX-AMCC sem convergência, retorno_op: 0.07428921752680773
# Par GD-WM sem convergência, retorno_op: -0.014635150253136331
# Par WHR-WM sem convergência, retorno_op: -0.05388724805016043
# Par AMAT-SBUX sem convergência, retorno_op: -0.0831432769646292
# Par HSH-BIG sem convergência, retorno_op: -0.014515484958943059
# Par 1312089D-WM sem convergência, retorno_op: -0.11973411731668682
# Par 3153670Q-SBUX sem convergência, retorno_op: -0.13903316375371233
# Par UNP-WM sem convergência, retorno_op: 0
# Par SVU-WM sem convergência, retorno_op: -0.0628166896934581
# Starting period 29 | Past days: 2400
# Reading csv
# Finished finding cointegrated pairs big_loop 29
# Found top cointegrated pairs big_loop 29
# Par XLNX-PMCS sem convergência, retorno_op: 0.0634773579733805
# Par ITW-UPS sem convergência, retorno_op: 0.025674906299896882
# Par AON-DVN sem convergência, retorno_op: -0.08598374523852081
# Par LLTC-MEDI sem convergência, retorno_op: -0.0569544149854635
# Par TRB-DYNIQ sem convergência, retorno_op: -0.0011352575168870338
# Par SEBL-CIEN sem convergência, retorno_op: -0.10834543363557714
# Par EMR-SYK sem convergência, retorno_op: -0.004128181090813143
# Par NKE-WAT sem convergência, retorno_op: -0.026903819470128765
# Par 0226226D-HMA sem convergência, retorno_op: -0.07216969484829594
# Par HSH-4621824Q sem convergência, retorno_op: 0.04493657137181062
# Par ADP-MCO sem convergência, retorno_op: -0.12983978309795852
# Par 0961514D-4621824Q sem convergência, retorno_op: 0
# Par FITB-4621824Q sem convergência, retorno_op: -0.018802989131883496
# Par 4621824Q-NFB sem convergência, retorno_op: -0.20334111648791708
# Starting period 30 | Past days: 2525
# Reading csv
# Finished finding cointegrated pairs big_loop 30
# Found top cointegrated pairs big_loop 30
# Par MKC-8277831Q sem convergência, retorno_op: -0.06241185987766373
# Par BMC-ODP sem convergência, retorno_op: 0.07925441202664985
# Par MCK-BIIB sem convergência, retorno_op: 0.058681372461608206
# Par CA-LH sem convergência, retorno_op: -0.040040333900293046
# Par VZ-ETR sem convergência, retorno_op: -0.0031020353555066826
# Par TRB-0544749D sem convergência, retorno_op: 0.02411478059531369
# Par CA-GENZ sem convergência, retorno_op: 0
# Par AVP-CB sem convergência, retorno_op: 0.007082935201442098
# Par MEL-CB sem convergência, retorno_op: 0.054113987428138
# Par BDX-CA sem convergência, retorno_op: -0.04310374915648074
# Starting period 31 | Past days: 2652
# Reading csv
# Finished finding cointegrated pairs big_loop 31
# Found top cointegrated pairs big_loop 31
# Par UTX-AMAT sem convergência, retorno_op: -0.1925766754184428
# Par ADP-KSS sem convergência, retorno_op: -0.11138477938894908
# Par CA-CTAS sem convergência, retorno_op: -0.04980747878110403
# Par BAC-SAF sem convergência, retorno_op: 0.004612948106221371
# Par SWK-3692470Q sem convergência, retorno_op: 0
# Par AXP-2968900Q sem convergência, retorno_op: -0.225034856153548
# Par DE-ADSK sem convergência, retorno_op: -0.28565322384335223
# Par CA-STT sem convergência, retorno_op: 0
# Par CPWR-TROW sem convergência, retorno_op: -0.3310931717990264
# Par HPC-BMC sem convergência, retorno_op: 0
# Par 0848680D-CFC sem convergência, retorno_op: -0.10885263650178789
# Par BBY-DGX sem convergência, retorno_op: -0.09264725780007144
# Par IBM-MMM sem convergência, retorno_op: -0.12172836741529824
# Par BMC-ADCT sem convergência, retorno_op: -0.09332577005308851
# Par TROW-ALTR sem convergência, retorno_op: -0.10737079157990093
# Par MDT-CA sem convergência, retorno_op: 0
# Starting period 32 | Past days: 2777
# Reading csv
# Finished finding cointegrated pairs big_loop 32
# Found top cointegrated pairs big_loop 32
# Par KMB-CEG sem convergência, retorno_op: -0.11475962524143757
# Par CEG-MTG sem convergência, retorno_op: -0.048359818582684344
# Par VFC-PCAR sem convergência, retorno_op: -0.0400033270398783
# Par MTLQQ-WFM sem convergência, retorno_op: -0.014189600863114826
# Par PG-CEG sem convergência, retorno_op: -0.0111443352912719
# Par CEG-CLX sem convergência, retorno_op: 0.0339513299366514
# Par CEG-PCL sem convergência, retorno_op: -0.008662837339298957
# Par TE-CNX sem convergência, retorno_op: -0.0705678532335694
# Par AEP-CNX sem convergência, retorno_op: -0.14127839331020864
# Par CEG-DF sem convergência, retorno_op: 0.05981856812848152
# Par CEG-MBI sem convergência, retorno_op: -0.009177733265575139
# Par EIX-SVU sem convergência, retorno_op: -0.09241642586959475
# Par PCG-FISV sem convergência, retorno_op: 0.03786475986189153
# Starting period 33 | Past days: 2903
# Reading csv
# Finished finding cointegrated pairs big_loop 33
# Found top cointegrated pairs big_loop 33
# Par DOW-MAT sem convergência, retorno_op: -0.020977609698787703
# Par SHW-USB sem convergência, retorno_op: -0.06657113116972413
# Par AGN-GILD sem convergência, retorno_op: -0.10966955133500456
# Par JNJ-3286728Q sem convergência, retorno_op: -0.050370367356479484
# Par IP-WM sem convergência, retorno_op: -0.0030898174971443204
# Par DOW-COL sem convergência, retorno_op: -0.04607056606743187
# Par MRK-GILD sem convergência, retorno_op: -0.11072259964600661
# Par PPG-STZ sem convergência, retorno_op: -0.02486774930355251
# Par HSH-GILD sem convergência, retorno_op: -0.19083945512058254
# Par 9876566D-BC sem convergência, retorno_op: 0.01098506408966271
# Starting period 34 | Past days: 3027
# Reading csv
# Finished finding cointegrated pairs big_loop 34
# Found top cointegrated pairs big_loop 34
# Par 0111145D-TMO sem convergência, retorno_op: -0.04154956518349051
# Par WAMUQ-HOT sem convergência, retorno_op: -0.020720813641127656
# Par EFX-OMC sem convergência, retorno_op: -0.02236791178565456
# Par XEL-CHK sem convergência, retorno_op: -0.04442323737056064
# Par WYE-OMC sem convergência, retorno_op: -0.00621089031035682
# Par DELL-TIF sem convergência, retorno_op: 0.04686863090575821
# Par IR-TMO sem convergência, retorno_op: -0.00871505804381334
# Par MER-OMC sem convergência, retorno_op: -0.03534627333034823
# Par CINF-RF sem convergência, retorno_op: 0.003434724238263076
# Par XEL-GENZ sem convergência, retorno_op: -0.007229274928997054
# Par ITW-CINF sem convergência, retorno_op: -0.016837960370590377
# Starting period 35 | Past days: 3154
# Reading csv
# Finished finding cointegrated pairs big_loop 35
# Found top cointegrated pairs big_loop 35
# Par HES-EOG sem convergência, retorno_op: 0.004592241698305077
# Par TWX-AGN sem convergência, retorno_op: -0.24911822799740024
# Par A-AMT sem convergência, retorno_op: -0.048612617469538044
# Par CMS-AMT sem convergência, retorno_op: 0.0020718098792433803
# Par PEG-SIAL sem convergência, retorno_op: -0.058662611854200186
# Par HES-APA sem convergência, retorno_op: -0.062003196228042956
# Par AES-CMS sem convergência, retorno_op: 0.012631725914984848
# Par AEP-PEG sem convergência, retorno_op: -0.046287482320436
# Par UTX-SWK sem convergência, retorno_op: 0.024410744483434943
# Par CMCSA-FHN sem convergência, retorno_op: 0.017497851297848754
# Par NEE-CMCSA sem convergência, retorno_op: 0.010978806949918596
# Par TWX-WAT sem convergência, retorno_op: -0.022318785164680666
# Par EL-ACAS sem convergência, retorno_op: 0.04830638856224212
# Par AEP-WAT sem convergência, retorno_op: -0.014024602485614768
# Par TRV-CMCSA sem convergência, retorno_op: 0.024400310445345852
# Par CMCSA-AEE sem convergência, retorno_op: 0.01702177359008905
# Starting period 36 | Past days: 3279
# Reading csv
# Finished finding cointegrated pairs big_loop 36
# Found top cointegrated pairs big_loop 36
# Par WY-MDLZ sem convergência, retorno_op: 0.0013391376217013473
# Par ABT-PPG sem convergência, retorno_op: -0.0096572540030877
# Par BDX-PBG sem convergência, retorno_op: -0.02721140324662441
# Par CBE-COST sem convergência, retorno_op: 0.006227772122344266
# Par MO-TLAB sem convergência, retorno_op: -0.040954423940412266
# Par DYNIQ-ISRG sem convergência, retorno_op: -0.1279291645599847
# Par CAT-TWX sem convergência, retorno_op: 0.02799715637092648
# Par MCD-M sem convergência, retorno_op: 0.0048694464119640735
# Par PCG-PGR sem convergência, retorno_op: 0.0046754281919176854
# Par LNC-FE sem convergência, retorno_op: -0.0027205312536491277
# Par ADM-VAR sem convergência, retorno_op: -0.04434428549373459
# Par LNC-BSX sem convergência, retorno_op: -0.007517838058195725
# Par HSH-DE sem convergência, retorno_op: 0.02543887310773041
# Par CAT-MDLZ sem convergência, retorno_op: -0.01818342553922392
# Par BEN-BMC sem convergência, retorno_op: -0.079410896085089
# Par BEN-FRX sem convergência, retorno_op: -0.05166949915338748
# Par CAT-ED sem convergência, retorno_op: -0.0431234014615578
# Starting period 37 | Past days: 3407
# Reading csv
# Finished finding cointegrated pairs big_loop 37
# Found top cointegrated pairs big_loop 37
# Par COL-EQR sem convergência, retorno_op: -0.023154395342076306
# Par APD-ALL sem convergência, retorno_op: -0.03412137663790338
# Par CTAS-ZBH sem convergência, retorno_op: 0.008382426689183209
# Par SRE-TSS sem convergência, retorno_op: -0.052703565535619834
# Par PFG-TSS sem convergência, retorno_op: -0.03241529356287565
# Par BLL-ROK sem convergência, retorno_op: -0.01702136729324355
# Par BLL-BTU sem convergência, retorno_op: -0.11297651515162688
# Par KEY-VMC sem convergência, retorno_op: -0.030638695834866336
# Par IFF-MET sem convergência, retorno_op: -0.08157484727585507
# Par RTN-TSS sem convergência, retorno_op: -0.00276106831855083
# Par BF_B-HIG sem convergência, retorno_op: -0.005605324769632158
# Starting period 38 | Past days: 3531
# Reading csv
# Finished finding cointegrated pairs big_loop 38
# Found top cointegrated pairs big_loop 38
# Par DELL-SPLS sem convergência, retorno_op: 0.012390595792137749
# Par PLL-KIM sem convergência, retorno_op: -0.05853019971362272
# Par TMK-MSFT sem convergência, retorno_op: 0.014942349567362623
# Par A-FTR sem convergência, retorno_op: -0.0007551802056409151
# Par BEN-1255459D sem convergência, retorno_op: -0.03108659467184438
# Par PLL-AVB sem convergência, retorno_op: -0.01422181152224633
# Par LM-1255459D sem convergência, retorno_op: 0.0008000658631877045
# Par MSI-HCN sem convergência, retorno_op: 0.021424195904890198
# Par UNH-1255459D sem convergência, retorno_op: 0.006400092873933172
# Par XL-FII sem convergência, retorno_op: 0.02453853283947982
# Par APH-1255459D sem convergência, retorno_op: -0.05687945863213839
# Par 9876566D-PSA sem convergência, retorno_op: 0.0022371616693979135
# Par VAR-1436513D sem convergência, retorno_op: -0.02129013514165745
# Par 0961514D-CCE sem convergência, retorno_op: 0.007591360300251093
# Starting period 39 | Past days: 3659
# Reading csv
# Finished finding cointegrated pairs big_loop 39
# Found top cointegrated pairs big_loop 39
# Par DF-VTR sem convergência, retorno_op: -0.07365935531820256
# Par AMD-RRC sem convergência, retorno_op: -0.1960781891334369
# Par INTU-MON sem convergência, retorno_op: -0.04507201591697907
# Par STI-CA sem convergência, retorno_op: -0.1477651240692146
# Par MMC-ROK sem convergência, retorno_op: -0.06792228045916726
# Par AMD-CBG sem convergência, retorno_op: -0.16320931679040918
# Par LOW-AMAT sem convergência, retorno_op: 0.00019314069902920394
# Par STT-DVA sem convergência, retorno_op: 0.10111575018313257
# Par GE-XRAY sem convergência, retorno_op: 0.00011290797297514032
# Par PLL-ALL sem convergência, retorno_op: -0.04001739992166087
# Par IBM-ROK sem convergência, retorno_op: -0.029407172745303356
# Par NWL-APH sem convergência, retorno_op: 0.02256351067793183
# Par MRK-PCLN sem convergência, retorno_op: 0.06880694185992153
# Par XRX-ROK sem convergência, retorno_op: -0.007779709883863006
# Starting period 40 | Past days: 3783
# Reading csv
# Finished finding cointegrated pairs big_loop 40
# Found top cointegrated pairs big_loop 40
# Par MMM-RHI sem convergência, retorno_op: -0.000627938220143065
# Par XRX-MCK sem convergência, retorno_op: 0.02412874971730794
# Par SIAL-XRAY sem convergência, retorno_op: -0.017769723582553354
# Par WHR-BK sem convergência, retorno_op: -0.009990574452355183
# Par TMK-RHI sem convergência, retorno_op: 0
# Par SCHW-MET sem convergência, retorno_op: -0.0011442577722786673
# Par RHI-XRAY sem convergência, retorno_op: -0.038561139172353265
# Par AVY-SCHW sem convergência, retorno_op: 0.004988380845705631
# Par AMGN-TE sem convergência, retorno_op: 0.0016964910590475668
# Par BAC-RHI sem convergência, retorno_op: 0.007287047605653019
# Par RL-DNB sem convergência, retorno_op: -0.010679585901243627
# Par UTX-RHI sem convergência, retorno_op: -0.023071709328998935
# Starting period 41 | Past days: 3911
# Reading csv
# Finished finding cointegrated pairs big_loop 41
# Found top cointegrated pairs big_loop 41
# Par INTC-CTSH sem convergência, retorno_op: -0.07894210863310391
# Par INTC-PH sem convergência, retorno_op: -0.02077483097735877
# Par PG-INTC sem convergência, retorno_op: -0.10163726549749397
# Par INTC-9876544D sem convergência, retorno_op: -0.07118663311870943
# Par INTC-DE sem convergência, retorno_op: 0.0056363631567548644
# Par HAL-YHOO sem convergência, retorno_op: -0.01387620914209764
# Par EOG-JEC sem convergência, retorno_op: -0.06552457611226048
# Par INTC-DRI sem convergência, retorno_op: -0.008765793301058089
# Par TRV-9876544D sem convergência, retorno_op: 0.04196360275143052
# Par INTC-DHR sem convergência, retorno_op: -0.020843009737766316
# Par INTC-EMR sem convergência, retorno_op: -0.028180823770595165
# Par INTC-NTAP sem convergência, retorno_op: -0.1702567446421126
# Par IBM-RRD sem convergência, retorno_op: -0.006996339774664406
# Par INTC-APH sem convergência, retorno_op: -0.047690897583354985
# Par FISV-9876544D sem convergência, retorno_op: 0.03757581175303626
# Par INTC-WAT sem convergência, retorno_op: -0.01834075619565745
# Starting period 42 | Past days: 4036
# Reading csv
# Finished finding cointegrated pairs big_loop 42
# Found top cointegrated pairs big_loop 42
# Par BMY-RL sem convergência, retorno_op: 0.02090570716378881
# Par MMM-CB sem convergência, retorno_op: -0.02885571280546806
# Par ETN-OKE sem convergência, retorno_op: 0.004136073119576977
# Par RRD-AET sem convergência, retorno_op: 0.022938952766957676
# Par AA-OKE sem convergência, retorno_op: 0.004700029242866499
# Par BBBY-EXPD sem convergência, retorno_op: -0.055824538536847435
# Par WFC-R sem convergência, retorno_op: 0.011710201335129344
# Par BAC-EXPD sem convergência, retorno_op: -0.010507528953281664
# Par MMM-XL sem convergência, retorno_op: -0.09589060356344037
# Par ANTM-GNW sem convergência, retorno_op: -0.09837589519996204
# Par TER-WIN sem convergência, retorno_op: -0.05487980381262059
# Par GWW-BAX sem convergência, retorno_op: -0.029949272535136018
# Par HP-OKE sem convergência, retorno_op: -0.16630310372781176
# Starting period 43 | Past days: 4163
# Reading csv
# Finished finding cointegrated pairs big_loop 43
# Found top cointegrated pairs big_loop 43
# Par BLL-SYMC sem convergência, retorno_op: -0.04855154107453519
# Par CTL-ORLY sem convergência, retorno_op: 0.000517551056408827
# Par GLW-A sem convergência, retorno_op: -0.06620170893256283
# Par NOC-SCHW sem convergência, retorno_op: -0.08049966116901697
# Par XL-FFIV sem convergência, retorno_op: -0.4885422696676769
# Par BEN-SYMC sem convergência, retorno_op: -0.03812130179718798
# Par TIF-SYMC sem convergência, retorno_op: -0.03580013867121279
# Par AA-SYMC sem convergência, retorno_op: -0.08549311829161432
# Par SWK-CTL sem convergência, retorno_op: -0.028425664484053037
# Par CSC-BEN sem convergência, retorno_op: -0.03910468024489022
# Par PFE-CINF sem convergência, retorno_op: -0.07342877834349171
# Par WMB-BWA sem convergência, retorno_op: -0.06221217860278605
# Par AGN-SYMC sem convergência, retorno_op: -0.01777750919245502
# Par UNM-VLO sem convergência, retorno_op: 0.0020755059002319776
# Par BMY-SYMC sem convergência, retorno_op: 0.010307512173945543
# Par AIG-WIN sem convergência, retorno_op: -0.2700445924707404
# Starting period 44 | Past days: 4288
# Reading csv
# Finished finding cointegrated pairs big_loop 44
# Found top cointegrated pairs big_loop 44
# Par ETR-LDOS sem convergência, retorno_op: 0.005842148578144801
# Par EFX-OMC sem convergência, retorno_op: -0.025922761959894736
# Par AGN-AVB sem convergência, retorno_op: -0.06350381392405247
# Par BMC-VRSN sem convergência, retorno_op: -0.06465867501961631
# Par CAT-EQR sem convergência, retorno_op: -0.04770778685244936
# Par BF_B-CCI sem convergência, retorno_op: 0.20593527465737793
# Par MO-BRK_B sem convergência, retorno_op: -0.015388146457425034
# Par PH-TROW sem convergência, retorno_op: 0.004699613472579411
# Par CBG-LUK sem convergência, retorno_op: 0.11921564848225552
# Par APD-PLL sem convergência, retorno_op: 0.07447327323756792
# Par GT-KMX sem convergência, retorno_op: 0.013803097311573254
# Starting period 45 | Past days: 4413
# Reading csv
# Finished finding cointegrated pairs big_loop 45
# Found top cointegrated pairs big_loop 45
# Par WAT-VNO sem convergência, retorno_op: -0.022834346347395673
# Par NOC-STT sem convergência, retorno_op: -0.05117046711971884
# Par HPQ-AVB sem convergência, retorno_op: -0.0020788072664705837
# Par BEN-MCO sem convergência, retorno_op: -0.004479854530528904
# Par SNA-WAT sem convergência, retorno_op: -0.1032126949307206
# Par WYNN-1436513D sem convergência, retorno_op: -0.158923840787498
# Par JCI-WYNN sem convergência, retorno_op: -0.1252442956562052
# Par ETN-OKE sem convergência, retorno_op: -0.04772125703611074
# Par CVS-MON sem convergência, retorno_op: -0.10434758045254044
# Par BHI-CAM sem convergência, retorno_op: 0.038744379113679006
# Starting period 46 | Past days: 4537
# Reading csv
# Finished finding cointegrated pairs big_loop 46
# Found top cointegrated pairs big_loop 46
# Par NVDA-ROST sem convergência, retorno_op: -0.1678349888768249
# Par NOC-ARG sem convergência, retorno_op: -0.004756889713537049
# Par CVS-ROP sem convergência, retorno_op: 0.1262422124456397
# Par KSS-NVDA sem convergência, retorno_op: -0.23385154516891138
# Par GPC-CB sem convergência, retorno_op: -0.010951422503523656
# Par EMC-FIS sem convergência, retorno_op: -0.005081093568534811
# Par CAT-ALL sem convergência, retorno_op: 0.04884325558814906
# Par BK-PAYX sem convergência, retorno_op: 0.04068584609992465
# Par WBA-EMC sem convergência, retorno_op: 0
# Par PBI-FAST sem convergência, retorno_op: -0.06677414985532204
# Starting period 47 | Past days: 4665
# Reading csv
# Finished finding cointegrated pairs big_loop 47
# Found top cointegrated pairs big_loop 47
# Par JPM-ALL sem convergência, retorno_op: 0.007246367328958669
# Par AFL-COG sem convergência, retorno_op: -0.03748248338155635
# Par MS-DVN sem convergência, retorno_op: -0.05021158180900498
# Par MS-APA sem convergência, retorno_op: -0.02249115024854298
# Par ALL-PDCO sem convergência, retorno_op: 0
# Par MMC-MS sem convergência, retorno_op: -0.06430790023897437
# Par MS-MUR sem convergência, retorno_op: -0.011906063956949264
# Par ALL-FIS sem convergência, retorno_op: -0.034854834874754825
# Par AFL-WDC sem convergência, retorno_op: -0.030398248065753197
# Par NEE-BK sem convergência, retorno_op: -0.09157929394960362
# Par CAG-DOV sem convergência, retorno_op: 0.002165386141875114
# Par ADP-GS sem convergência, retorno_op: -0.00044805333188246976
# Starting period 48 | Past days: 4789
# Reading csv
# Finished finding cointegrated pairs big_loop 48
# Found top cointegrated pairs big_loop 48
# Par VTR-AME sem convergência, retorno_op: -0.03267891575577986
# Par ICE-RSG sem convergência, retorno_op: 0.036168793985549286
# Par PPG-ICE sem convergência, retorno_op: -0.03001708468894737
# Par AXP-ICE sem convergência, retorno_op: 0.014197857329334873
# Par SYY-AME sem convergência, retorno_op: -0.031507184442968406
# Par CPB-ICE sem convergência, retorno_op: -0.014045099625377588
# Par THC-EA sem convergência, retorno_op: 0.03087891872031756
# Par ICE-TDC sem convergência, retorno_op: 0.03861491818661733
# Par ICE-HCN sem convergência, retorno_op: 0.028558490912063306
# Par UNP-PSA sem convergência, retorno_op: 0.0019269300550921464
# Par VFC-ICE sem convergência, retorno_op: 0.02186090829780607
# Par DIS-AME sem convergência, retorno_op: -0.018499852870448308
# Par CAT-ICE sem convergência, retorno_op: -0.04356371503629086

# %%
pd.DataFrame(Rpair).to_csv("../cointegration_results/Rpair.csv", header=None, index=False)
daily_returns = np.sum(Rpair, axis=1)
pd.DataFrame(daily_returns).to_csv("../cointegration_results/daily_returns.csv", header=None, index=False)
